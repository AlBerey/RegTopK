# %% [markdown]
# # RegTopK vs TopK for Fine Tuning Models on ImageNette
# In this notebook, we fine tune various models on ImageNette using both TopK and RegTopK algorithms and compare the results together.

# %%
# Install fastai and torchvision if not already installed
# !pip install -q fastai torchvision

# Import Libraries
from fastai.vision.all import *
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset, Subset
import torch
import random

# Download ImageNette (160px version, ~160MB)
path = untar_data(URLs.IMAGENETTE_160)
print(f"Data downloaded to: {path}")

# Show class folders
print("Classes:", (path/'train').ls())
# Out:
# Data downloaded to: /Users/alibereyhi/.fastai/data/imagenette2-160
# Classes: [Path('/Users/alibereyhi/.fastai/data/imagenette2-160/train/n03394916'), Path('/Users/alibereyhi/.fastai/data/imagenette2-160/train/n03417042'), Path('/Users/alibereyhi/.fastai/data/imagenette2-160/train/.DS_Store'), Path('/Users/alibereyhi/.fastai/data/imagenette2-160/train/n03445777'), Path('/Users/alibereyhi/.fastai/data/imagenette2-160/train/n02102040'), Path('/Users/alibereyhi/.fastai/data/imagenette2-160/train/n03425413'), Path('/Users/alibereyhi/.fastai/data/imagenette2-160/train/n03888257'), Path('/Users/alibereyhi/.fastai/data/imagenette2-160/train/n03028079'), Path('/Users/alibereyhi/.fastai/data/imagenette2-160/train/n03000684'), Path('/Users/alibereyhi/.fastai/data/imagenette2-160/train/n01440764'), Path('/Users/alibereyhi/.fastai/data/imagenette2-160/train/n02979186')]

# %% [markdown]
# ## Let's Setup Network
# We set up the network of workers and share the data among them.

# %%
import torch
import random
import numpy as np
from torchvision.datasets import ImageFolder
import os
from sklearn.model_selection import train_test_split
import torch.nn.functional as F

# Set the seed for fairness
def set_seed(seed=42):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    random.seed(seed)
    np.random.seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# Set the seed for data shuffeling
set_seed()

# Set the device
device = torch.device("mps")#"cuda" if torch.cuda.is_available() else "cpu")

# Define transforms (resize to 128x128, normalize)
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize([0.5]*3, [0.5]*3)
])

# Load the training and validation sets
train_dataset = ImageFolder(root=os.path.join(path, 'train'), transform=transform)
val_dataset   = ImageFolder(root=os.path.join(path, 'val'), transform=transform)

print(f"Total training samples: {len(train_dataset)}")
print(f"Total validation samples: {len(val_dataset)}")
print(f"Classes: {train_dataset.classes}")
# Out:
# Total training samples: 9469
# Total validation samples: 3925
# Classes: ['n01440764', 'n02102040', 'n02979186', 'n03000684', 'n03028079', 'n03394916', 'n03417042', 'n03425413', 'n03445777', 'n03888257']

# %% [markdown]
# ### Model preprocessing
# Here, we prepare the model for finetuning on ImageNette

# %%
# Prepare model for finetuning on ImageNette
def model_loader(model):
  # Freeze all layers
  for param in model.parameters():
      param.requires_grad = False

  # Replace classifier with trainable layer
  num_classes = len(train_dataset.classes)
  model.classifier[1] = torch.nn.Linear(model.last_channel, num_classes)

  # Only the final layer is trainable
  for param in model.classifier[1].parameters():
      param.requires_grad = True

  model = model.to(device)
  print(f"device is {device}")
  return model

# %% [markdown]
# ### Build data loaders
# We build data loaders for training and validation

# %%
# We set the number of users
num_users = 20

# Shuffle and split indices uniformly
train_indices = list(range(len(train_dataset)))
random.shuffle(train_indices)

# Uniform splits
user_indices = torch.chunk(torch.tensor(train_indices), num_users)

# Create subset datasets and DataLoaders for each user
user_dataloaders = []

for i, indices in enumerate(user_indices):
    subset = Subset(train_dataset, indices)
    loader = DataLoader(subset, batch_size=64, shuffle=True, num_workers=2)
    user_dataloaders.append(loader)
    print(f"User {i+1}: {len(subset)} samples")

val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False, num_workers=2)
# Out:
# User 1: 474 samples
# User 2: 474 samples
# User 3: 474 samples
# User 4: 474 samples
# User 5: 474 samples
# User 6: 474 samples
# User 7: 474 samples
# User 8: 474 samples
# User 9: 474 samples
# User 10: 474 samples
# User 11: 474 samples
# User 12: 474 samples
# User 13: 474 samples
# User 14: 474 samples
# User 15: 474 samples
# User 16: 474 samples
# User 17: 474 samples
# User 18: 474 samples
# User 19: 474 samples
# User 20: 463 samples

# %% [markdown]
# ## Evaluation
# This is the evaluation function used to check training results.

# %%
def evaluate(model, val_loader):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, targets in val_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            correct += (predicted == targets).sum().item()
            total += targets.size(0)
    return correct / total

# %% [markdown]
# ## TopK
# We now implement the training loop for TopK

# %%
# This is the TopK sparsifier
def topk_sparsify(tensor, k_frac=0.01):
    """Keep top-k fraction of values in tensor; set rest to zero"""
    if tensor is None:
        return None
    tensor_flat = tensor.view(-1)
    k = max(1, int(k_frac * tensor_flat.numel()))
    if k == tensor_flat.numel():
        return tensor
    topk_vals, topk_idx = torch.topk(tensor_flat.abs(), k)
    mask = torch.zeros_like(tensor_flat)
    mask[topk_idx] = 1.0
    return (tensor_flat * mask).view_as(tensor)

# %%
# And the training loop
def train_TopK(model, user_dataloaders, val_loader, epochs=5, lr=0.01, k_frac=0.01):
    optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=0.9)

    val_accuracies = []
    val_losses = []

    for epoch in range(1, epochs + 1):
        model.train()
        running_loss = 0
        batch_count = 0

        for user_loader in user_dataloaders:
            for inputs, targets in user_loader:
                inputs, targets = inputs.to(device), targets.to(device)
                optimizer.zero_grad()
                outputs = model(inputs)
                loss = F.cross_entropy(outputs, targets)
                loss.backward()

                # TopK sparsify gradients
                with torch.no_grad():
                    for param in model.parameters():
                        if param.grad is not None:
                            param.grad.data = topk_sparsify(param.grad.data, k_frac=k_frac)

                optimizer.step()
                running_loss += loss.item()
                batch_count += 1

        avg_loss = running_loss / batch_count
        val_acc = evaluate(model, val_loader)
        val_accuracies.append(val_acc)
        val_losses.append(avg_loss)

        print(f"Epoch {epoch}/{epochs} - Loss: {avg_loss:.4f} - Val Acc: {val_acc:.4f}")

    return val_accuracies, val_losses

# %% [markdown]
# # RegTopK
# We now implement the sparsifier and training loop for RegTopK

# %%
# This is the RegTopK Sparsifier
class RegTopK:
    def __init__(self, model, k_frac=0.1, mu=2.0, omega=.05, Q=1e8):
        self.k_frac = k_frac
        self.mu = mu
        self.omega = omega
        self.Q = Q
        self.eps = {}         # Sparsification error (ε)
        self.prev_grad = {}   # Previous global gradient g_{t-1}
        self.a_prev = {}      # Previous accumulated gradient a_{t-1}
        self.mask = {}        # Previous mask s_{t-1}

        for name, param in model.named_parameters():
            self.eps[name] = torch.zeros_like(param.data)
            self.prev_grad[name] = torch.zeros_like(param.data)
            self.a_prev[name] = torch.zeros_like(param.data)
            self.mask[name] = torch.zeros_like(param.data)

    def sparsify(self, name, grad):
        if grad is None:
            return None

        eps = self.eps[name]
        g_prev = self.prev_grad[name]
        a_prev = self.a_prev[name]
        s_prev = self.mask[name]

        # Accumulated gradient a_t
        a_t = grad + eps

        # Posterior distortion δ
        numerator = g_prev - self.omega * a_prev
        denominator = self.omega * a_t + 1e-10  # prevent div by zero
        delta = s_prev * (numerator / denominator) + self.Q * (1 - s_prev)

        # Importance weights
        weight = torch.tanh(torch.abs(1 + delta) / self.mu)

        # Compute sparsity mask via weighted TopK
        importance = torch.abs(a_t * weight).flatten()
        k = max(1, int(self.k_frac * importance.numel()))
        topk_vals, topk_idx = torch.topk(importance, k)
        mask_flat = torch.zeros_like(importance)
        mask_flat[topk_idx] = 1.0
        mask = mask_flat.view_as(a_t)

        # Apply mask
        sparse_grad = a_t * mask

        # Update memory
        self.eps[name] = a_t - sparse_grad
        self.prev_grad[name] = grad.detach().clone()
        self.a_prev[name] = a_t.detach().clone()
        self.mask[name] = mask.detach().clone()

        return sparse_grad

# %%
# And this is the train loop with RegTopK
def train_regTopK(model, user_dataloaders, val_loader, epochs=5, lr=0.01, k_frac=0.01):
    optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=0.9)
    omega = 1/num_users
    sparsifier = RegTopK(model, k_frac=k_frac, mu=2.0, omega=omega, Q=10000.0)

    val_accuracies = []
    val_losses = []

    for epoch in range(1, epochs + 1):
        model.train()
        running_loss = 0
        batch_count = 0

        for user_loader in user_dataloaders:
            for inputs, targets in user_loader:
                inputs, targets = inputs.to(device), targets.to(device)
                optimizer.zero_grad()
                outputs = model(inputs)
                loss = F.cross_entropy(outputs, targets)
                loss.backward()

                # RegTopK sparsify gradients
                with torch.no_grad():
                  for name, param in model.named_parameters():
                    if param.grad is not None:
                      param.grad.data = sparsifier.sparsify(name, param.grad.data)

                optimizer.step()
                running_loss += loss.item()
                batch_count += 1

        avg_loss = running_loss / batch_count
        val_acc = evaluate(model, val_loader)
        val_accuracies.append(val_acc)
        val_losses.append(avg_loss)

        print(f"Epoch {epoch}/{epochs} - Loss: {avg_loss:.4f} - Val Acc: {val_acc:.4f}")

    return val_accuracies, val_losses

# %% [markdown]
# # MobileNetV2
# Here, we finetune MobileNetV2 with both TopK and RegTopK

# %%
from torchvision.models import mobilenet_v2
seeds = [42, 43, 44, 45, 46, 51, 52, 53, 54, 55]
k_frac = 0.001

# %% [markdown]
# #### TopK

# %%
max_accs_topK = []
min_losses_topK = []

last_accs_topK = []
last_losses_topK = []

for seed in seeds:
    print(f"\n==== Running with seed {seed} ====")

    # Set seed
    set_seed(seed)

    # Load and prepare model
    model = mobilenet_v2(weights=MobileNet_V2_Weights.IMAGENET1K_V1)
    model = model_loader(model)

    # Train with TopK
    val_accs, val_losses = train_TopK(model, user_dataloaders, val_loader, epochs=8, lr=0.01, k_frac=k_frac)

    # Record max accuracy and min loss
    max_accs_topK.append(max(val_accs))
    min_losses_topK.append(min(val_losses))

    # Record last accuracy and loss
    last_accs_topK.append(val_accs[-1])
    last_losses_topK.append(val_losses[-1])

# Report results
print("\n===== Summary over seeds =====")
print(f"Max Val Accuracy: mean = {np.mean(max_accs_topK):.4f}, std = {np.std(max_accs_topK):.4f}")
print(f"Min Val Loss:     mean = {np.mean(min_losses_topK):.4f}, std = {np.std(min_losses_topK):.4f}")
print(f"Last-epoch Val Accuracy: mean = {np.mean(last_accs_topK):.4f}, std = {np.std(last_accs_topK):.4f}")
print(f"Last-epoch Val Loss:     mean = {np.mean(last_losses_topK):.4f}, std = {np.std(last_losses_topK):.4f}")
# Out:
# ==== Running with seed 42 ====
# device is mps
# Epoch 1/8 - Loss: 1.4301 - Val Acc: 0.8494
# Epoch 2/8 - Loss: 0.7041 - Val Acc: 0.8856
# Epoch 3/8 - Loss: 0.5420 - Val Acc: 0.8940
# Epoch 4/8 - Loss: 0.4744 - Val Acc: 0.8955
# Epoch 5/8 - Loss: 0.4179 - Val Acc: 0.8986
# Epoch 6/8 - Loss: 0.3905 - Val Acc: 0.9032
# Epoch 7/8 - Loss: 0.3708 - Val Acc: 0.9024
# Epoch 8/8 - Loss: 0.3583 - Val Acc: 0.9027
#
# ==== Running with seed 43 ====
# device is mps
# Epoch 1/8 - Loss: 1.4120 - Val Acc: 0.8548
# Epoch 2/8 - Loss: 0.6856 - Val Acc: 0.8820
# Epoch 3/8 - Loss: 0.5289 - Val Acc: 0.8917
# Epoch 4/8 - Loss: 0.4536 - Val Acc: 0.8973
# Epoch 5/8 - Loss: 0.4113 - Val Acc: 0.9014
# Epoch 6/8 - Loss: 0.3737 - Val Acc: 0.9029
# Epoch 7/8 - Loss: 0.3622 - Val Acc: 0.9060
# Epoch 8/8 - Loss: 0.3481 - Val Acc: 0.9080
#
# ==== Running with seed 44 ====
# device is mps
# Epoch 1/8 - Loss: 1.4349 - Val Acc: 0.8520
# Epoch 2/8 - Loss: 0.7034 - Val Acc: 0.8871
# Epoch 3/8 - Loss: 0.5416 - Val Acc: 0.8930
# Epoch 4/8 - Loss: 0.4619 - Val Acc: 0.8953
# Epoch 5/8 - Loss: 0.4160 - Val Acc: 0.9017
# Epoch 6/8 - Loss: 0.3802 - Val Acc: 0.9037
# Epoch 7/8 - Loss: 0.3730 - Val Acc: 0.9060
# Epoch 8/8 - Loss: 0.3502 - Val Acc: 0.9098
#
# ==== Running with seed 45 ====
# device is mps
# Epoch 1/8 - Loss: 1.5279 - Val Acc: 0.8448
# Epoch 2/8 - Loss: 0.7335 - Val Acc: 0.8838
# Epoch 3/8 - Loss: 0.5479 - Val Acc: 0.8932
# Epoch 4/8 - Loss: 0.4731 - Val Acc: 0.8958
# Epoch 5/8 - Loss: 0.4199 - Val Acc: 0.9024
# Epoch 6/8 - Loss: 0.3840 - Val Acc: 0.9039
# Epoch 7/8 - Loss: 0.3742 - Val Acc: 0.9047
# Epoch 8/8 - Loss: 0.3580 - Val Acc: 0.9047
#
# ==== Running with seed 46 ====
# device is mps
# Epoch 1/8 - Loss: 1.4527 - Val Acc: 0.8413
# Epoch 2/8 - Loss: 0.7115 - Val Acc: 0.8805
# Epoch 3/8 - Loss: 0.5365 - Val Acc: 0.8945
# Epoch 4/8 - Loss: 0.4653 - Val Acc: 0.8966
# Epoch 5/8 - Loss: 0.4143 - Val Acc: 0.8963
# Epoch 6/8 - Loss: 0.3815 - Val Acc: 0.9011
# Epoch 7/8 - Loss: 0.3739 - Val Acc: 0.9024
# Epoch 8/8 - Loss: 0.3576 - Val Acc: 0.9052
#
# ==== Running with seed 51 ====
# device is mps
# Epoch 1/8 - Loss: 1.4591 - Val Acc: 0.8448
# Epoch 2/8 - Loss: 0.7071 - Val Acc: 0.8782
# Epoch 3/8 - Loss: 0.5321 - Val Acc: 0.8897
# Epoch 4/8 - Loss: 0.4654 - Val Acc: 0.8973
# Epoch 5/8 - Loss: 0.4128 - Val Acc: 0.9009
# Epoch 6/8 - Loss: 0.3856 - Val Acc: 0.9037
# Epoch 7/8 - Loss: 0.3666 - Val Acc: 0.9042
# Epoch 8/8 - Loss: 0.3470 - Val Acc: 0.9037
#
# ==== Running with seed 52 ====
# device is mps
# Epoch 1/8 - Loss: 1.4015 - Val Acc: 0.8586
# Epoch 2/8 - Loss: 0.6970 - Val Acc: 0.8836
# Epoch 3/8 - Loss: 0.5382 - Val Acc: 0.8963
# Epoch 4/8 - Loss: 0.4646 - Val Acc: 0.9009
# Epoch 5/8 - Loss: 0.4141 - Val Acc: 0.9068
# Epoch 6/8 - Loss: 0.3777 - Val Acc: 0.9065
# Epoch 7/8 - Loss: 0.3656 - Val Acc: 0.9080
# Epoch 8/8 - Loss: 0.3493 - Val Acc: 0.9118
#
# ==== Running with seed 53 ====
# device is mps
# Epoch 1/8 - Loss: 1.4472 - Val Acc: 0.8466
# Epoch 2/8 - Loss: 0.7104 - Val Acc: 0.8833
# Epoch 3/8 - Loss: 0.5369 - Val Acc: 0.8920
# Epoch 4/8 - Loss: 0.4557 - Val Acc: 0.8971
# Epoch 5/8 - Loss: 0.4176 - Val Acc: 0.9011
# Epoch 6/8 - Loss: 0.3857 - Val Acc: 0.9057
# Epoch 7/8 - Loss: 0.3660 - Val Acc: 0.9047
# Epoch 8/8 - Loss: 0.3481 - Val Acc: 0.9124
#
# ==== Running with seed 54 ====
# device is mps
# Epoch 1/8 - Loss: 1.4663 - Val Acc: 0.8487
# Epoch 2/8 - Loss: 0.7141 - Val Acc: 0.8846
# Epoch 3/8 - Loss: 0.5522 - Val Acc: 0.8955
# Epoch 4/8 - Loss: 0.4644 - Val Acc: 0.9022
# Epoch 5/8 - Loss: 0.4221 - Val Acc: 0.9024
# Epoch 6/8 - Loss: 0.3902 - Val Acc: 0.9060
# Epoch 7/8 - Loss: 0.3739 - Val Acc: 0.9090
# Epoch 8/8 - Loss: 0.3488 - Val Acc: 0.9126
#
# ==== Running with seed 55 ====
# device is mps
# Epoch 1/8 - Loss: 1.4175 - Val Acc: 0.8553
# Epoch 2/8 - Loss: 0.7022 - Val Acc: 0.8813
# Epoch 3/8 - Loss: 0.5369 - Val Acc: 0.8922
# Epoch 4/8 - Loss: 0.4594 - Val Acc: 0.9001
# Epoch 5/8 - Loss: 0.4202 - Val Acc: 0.9055
# Epoch 6/8 - Loss: 0.3942 - Val Acc: 0.9034
# Epoch 7/8 - Loss: 0.3705 - Val Acc: 0.9070
# Epoch 8/8 - Loss: 0.3560 - Val Acc: 0.9088
#
# ===== Summary over seeds =====
# Max Val Accuracy: mean = 0.9081, std = 0.0034
# Min Val Loss:     mean = 0.3521, std = 0.0045
# Last-epoch Val Accuracy: mean = 0.9080, std = 0.0035
# Last-epoch Val Loss:     mean = 0.3521, std = 0.0045

# %%
# Folder and file name
# save_dir = "/content/drive/MyDrive/RegTopK/MobileNetV2"
save_dir = "MobileNetV2"
os.makedirs(save_dir, exist_ok=True)
filename = os.path.join(save_dir, f"TopK_{k_frac}.txt")

# Vectors
results = {
    "Max Val Accuracy": max_accs_topK,
    "Min Val Loss": min_losses_topK,
    "Last-epoch Val Accuracy": last_accs_topK,
    "Last-epoch Val Loss": last_losses_topK,
}

# Write to file
with open(filename, "w") as f:
    f.write(f"=== TopK Results Summary (MobileNetV2) for k={k_frac} ===\n\n")
    for name, values in results.items():
        mean = np.mean(values)
        std = np.std(values)
        f.write(f"{name}:\n")
        f.write(f"  Values: {np.round(values, 4).tolist()}\n")
        f.write(f"  Mean  : {mean:.4f}\n")
        f.write(f"  Std   : {std:.4f}\n\n")

print(f"Results saved to {filename}")
# Out:
# Results saved to MobileNetV2/TopK_0.001.txt

# %% [markdown]
# #### RegTopK

# %%
max_accs_regTopK = []
min_losses_regTopK = []

last_accs_regTopK = []
last_losses_regTopK = []

for seed in seeds:
    print(f"\n==== Running with seed {seed} ====")

    # Set seed
    set_seed(seed)

    # Load and prepare model
    model = mobilenet_v2(weights=MobileNet_V2_Weights.IMAGENET1K_V1)
    model = model_loader(model)

    # Train with TopK
    val_accs, val_losses = train_regTopK(model, user_dataloaders, val_loader, epochs=8, lr=0.01, k_frac=k_frac)

    # Record max accuracy and min loss
    max_accs_regTopK.append(max(val_accs))
    min_losses_regTopK.append(min(val_losses))

    # Record last accuracy and loss
    last_accs_regTopK.append(val_accs[-1])
    last_losses_regTopK.append(val_losses[-1])

# Report results
print("\n===== Summary over seeds for RegTopK =====")
print(f"Max Val Accuracy: mean = {np.mean(max_accs_regTopK):.4f}, std = {np.std(max_accs_regTopK):.4f}")
print(f"Min Val Loss:     mean = {np.mean(min_losses_regTopK):.4f}, std = {np.std(min_losses_regTopK):.4f}")
print(f"Last-epoch Val Accuracy: mean = {np.mean(last_accs_regTopK):.4f}, std = {np.std(last_accs_regTopK):.4f}")
print(f"Last-epoch Val Loss:     mean = {np.mean(last_losses_regTopK):.4f}, std = {np.std(last_losses_regTopK):.4f}")
# Out:
# ==== Running with seed 42 ====
# device is mps
# Epoch 1/8 - Loss: 0.7362 - Val Acc: 0.9093
# Epoch 2/8 - Loss: 0.3269 - Val Acc: 0.9233
# Epoch 3/8 - Loss: 0.2964 - Val Acc: 0.9254
# Epoch 4/8 - Loss: 0.2876 - Val Acc: 0.9264
# Epoch 5/8 - Loss: 0.2484 - Val Acc: 0.9279
# Epoch 6/8 - Loss: 0.2081 - Val Acc: 0.9248
# Epoch 7/8 - Loss: 0.1928 - Val Acc: 0.9287
# Epoch 8/8 - Loss: 0.1795 - Val Acc: 0.9312
#
# ==== Running with seed 43 ====
# device is mps
# Epoch 1/8 - Loss: 0.6957 - Val Acc: 0.9070
# Epoch 2/8 - Loss: 0.3312 - Val Acc: 0.9185
# Epoch 3/8 - Loss: 0.3104 - Val Acc: 0.9315
# Epoch 4/8 - Loss: 0.2642 - Val Acc: 0.9292
# Epoch 5/8 - Loss: 0.2484 - Val Acc: 0.9310
# Epoch 6/8 - Loss: 0.2134 - Val Acc: 0.9299
# Epoch 7/8 - Loss: 0.2023 - Val Acc: 0.9304
# Epoch 8/8 - Loss: 0.1852 - Val Acc: 0.9320
#
# ==== Running with seed 44 ====
# device is mps
# Epoch 1/8 - Loss: 0.7846 - Val Acc: 0.9055
# Epoch 2/8 - Loss: 0.3468 - Val Acc: 0.9231
# Epoch 3/8 - Loss: 0.3307 - Val Acc: 0.9287
# Epoch 4/8 - Loss: 0.2872 - Val Acc: 0.9259
# Epoch 5/8 - Loss: 0.2479 - Val Acc: 0.9251
# Epoch 6/8 - Loss: 0.2209 - Val Acc: 0.9276
# Epoch 7/8 - Loss: 0.2177 - Val Acc: 0.9271
# Epoch 8/8 - Loss: 0.1862 - Val Acc: 0.9284
#
# ==== Running with seed 45 ====
# device is mps
# Epoch 1/8 - Loss: 0.7732 - Val Acc: 0.9088
# Epoch 2/8 - Loss: 0.3428 - Val Acc: 0.9203
# Epoch 3/8 - Loss: 0.3161 - Val Acc: 0.9294
# Epoch 4/8 - Loss: 0.2984 - Val Acc: 0.9299
# Epoch 5/8 - Loss: 0.2372 - Val Acc: 0.9327
# Epoch 6/8 - Loss: 0.2142 - Val Acc: 0.9325
# Epoch 7/8 - Loss: 0.1976 - Val Acc: 0.9343
# Epoch 8/8 - Loss: 0.1841 - Val Acc: 0.9317
#
# ==== Running with seed 46 ====
# device is mps
# Epoch 1/8 - Loss: 0.7412 - Val Acc: 0.9073
# Epoch 2/8 - Loss: 0.3438 - Val Acc: 0.9218
# Epoch 3/8 - Loss: 0.3056 - Val Acc: 0.9282
# Epoch 4/8 - Loss: 0.2885 - Val Acc: 0.9304
# Epoch 5/8 - Loss: 0.2508 - Val Acc: 0.9274
# Epoch 6/8 - Loss: 0.2244 - Val Acc: 0.9297
# Epoch 7/8 - Loss: 0.1981 - Val Acc: 0.9284
# Epoch 8/8 - Loss: 0.1857 - Val Acc: 0.9279
#
# ==== Running with seed 51 ====
# device is mps
# Epoch 1/8 - Loss: 0.7368 - Val Acc: 0.9045
# Epoch 2/8 - Loss: 0.3222 - Val Acc: 0.9236
# Epoch 3/8 - Loss: 0.2932 - Val Acc: 0.9271
# Epoch 4/8 - Loss: 0.2756 - Val Acc: 0.9307
# Epoch 5/8 - Loss: 0.2472 - Val Acc: 0.9254
# Epoch 6/8 - Loss: 0.2368 - Val Acc: 0.9297
# Epoch 7/8 - Loss: 0.1968 - Val Acc: 0.9289
# Epoch 8/8 - Loss: 0.1810 - Val Acc: 0.9243
#
# ==== Running with seed 52 ====
# device is mps
# Epoch 1/8 - Loss: 0.7735 - Val Acc: 0.9078
# Epoch 2/8 - Loss: 0.3555 - Val Acc: 0.9205
# Epoch 3/8 - Loss: 0.3135 - Val Acc: 0.9259
# Epoch 4/8 - Loss: 0.2905 - Val Acc: 0.9254
# Epoch 5/8 - Loss: 0.2401 - Val Acc: 0.9276
# Epoch 6/8 - Loss: 0.2054 - Val Acc: 0.9292
# Epoch 7/8 - Loss: 0.2028 - Val Acc: 0.9259
# Epoch 8/8 - Loss: 0.1854 - Val Acc: 0.9299
#
# ==== Running with seed 53 ====
# device is mps
# Epoch 1/8 - Loss: 0.7130 - Val Acc: 0.9116
# Epoch 2/8 - Loss: 0.3261 - Val Acc: 0.9182
# Epoch 3/8 - Loss: 0.2955 - Val Acc: 0.9289
# Epoch 4/8 - Loss: 0.2631 - Val Acc: 0.9284
# Epoch 5/8 - Loss: 0.2544 - Val Acc: 0.9261
# Epoch 6/8 - Loss: 0.2200 - Val Acc: 0.9302
# Epoch 7/8 - Loss: 0.1909 - Val Acc: 0.9271
# Epoch 8/8 - Loss: 0.1837 - Val Acc: 0.9269
#
# ==== Running with seed 54 ====
# device is mps
# Epoch 1/8 - Loss: 0.7485 - Val Acc: 0.9113
# Epoch 2/8 - Loss: 0.3448 - Val Acc: 0.9182
# Epoch 3/8 - Loss: 0.3267 - Val Acc: 0.9231
# Epoch 4/8 - Loss: 0.3053 - Val Acc: 0.9279
# Epoch 5/8 - Loss: 0.2493 - Val Acc: 0.9266
# Epoch 6/8 - Loss: 0.2177 - Val Acc: 0.9287
# Epoch 7/8 - Loss: 0.2078 - Val Acc: 0.9292
# Epoch 8/8 - Loss: 0.1833 - Val Acc: 0.9284
#
# ==== Running with seed 55 ====
# device is mps
# Epoch 1/8 - Loss: 0.7288 - Val Acc: 0.9083
# Epoch 2/8 - Loss: 0.3197 - Val Acc: 0.9215
# Epoch 3/8 - Loss: 0.3038 - Val Acc: 0.9264
# Epoch 4/8 - Loss: 0.2784 - Val Acc: 0.9302
# Epoch 5/8 - Loss: 0.2615 - Val Acc: 0.9299
# Epoch 6/8 - Loss: 0.2208 - Val Acc: 0.9294
# Epoch 7/8 - Loss: 0.1919 - Val Acc: 0.9276
# Epoch 8/8 - Loss: 0.1822 - Val Acc: 0.9320
#
# ===== Summary over seeds for RegTopK =====
# Max Val Accuracy: mean = 0.9309, std = 0.0015
# Min Val Loss:     mean = 0.1836, std = 0.0021
# Last-epoch Val Accuracy: mean = 0.9293, std = 0.0024
# Last-epoch Val Loss:     mean = 0.1836, std = 0.0021

# %%
# Folder and file name
# save_dir = "/content/drive/MyDrive/RegTopK/MobileNetV2"
save_dir = "MobileNetV2"
os.makedirs(save_dir, exist_ok=True)
filename = os.path.join(save_dir, f"RegTopK_{k_frac}.txt")

# Vectors
results = {
    "Max Val Accuracy": max_accs_regTopK,
    "Min Val Loss": min_losses_regTopK,
    "Last-epoch Val Accuracy": last_accs_regTopK,
    "Last-epoch Val Loss": last_losses_regTopK,
}

# Write to file
with open(filename, "w") as f:
    f.write(f"=== RegTopK Results Summary (MobileNetV2) for k={k_frac} ===\n\n")
    for name, values in results.items():
        mean = np.mean(values)
        std = np.std(values)
        f.write(f"{name}:\n")
        f.write(f"  Values: {np.round(values, 4).tolist()}\n")
        f.write(f"  Mean  : {mean:.4f}\n")
        f.write(f"  Std   : {std:.4f}\n\n")

print(f"Results saved to {filename}")
# Out:
# Results saved to MobileNetV2/RegTopK_0.001.txt

# %% [markdown]
# #### Check Statistical Significance

# %%
from scipy.stats import ttest_rel, wilcoxon

# Paired t-test
t_stat, p_val_acc = ttest_rel(max_accs_regTopK, max_accs_topK)
print(f"Paired t-test on Accuracy: p = {p_val_acc:.5f}")

# Paired t-test
t_stat, p_val_loss = ttest_rel(min_losses_regTopK, min_losses_topK)
print(f"Paired t-test on loss: p = {p_val_loss:.5f}")

# Wilcoxon signed-rank test
w_stat, p_val_w_acc = wilcoxon(max_accs_regTopK, max_accs_topK)
print(f"Wilcoxon test on Accuracy: p = {p_val_w_acc:.5f}")

w_stat, p_val_w_loss = wilcoxon(min_losses_regTopK, min_losses_topK)
print(f"Wilcoxon test on loss: p = {p_val_w_loss:.5f}")
# Out:
# Paired t-test on Accuracy: p = 0.00000
# Paired t-test on loss: p = 0.00000
# Wilcoxon test on Accuracy: p = 0.00195
# Wilcoxon test on loss: p = 0.00195

# %%
save_dir = "MobileNetV2"
os.makedirs(save_dir, exist_ok=True)
filename = os.path.join(save_dir, f"p_values_{k_frac}.txt")

with open(filename, "w") as f:
    f.write(f"=== Statistical Significance (p-values) for k={k_frac} ===\n\n")
    f.write(f"Paired t-test on Accuracy: p = {p_val_acc:.5f}\n")
    f.write(f"Paired t-test on Loss:     p = {p_val_loss:.5f}\n")
    f.write(f"Wilcoxon test on Accuracy: p = {p_val_w_acc:.5f}\n")
    f.write(f"Wilcoxon test on Loss:     p = {p_val_w_loss:.5f}\n")

print(f"\n p-values saved to {filename}")
# Out:
#  p-values saved to MobileNetV2/p_values_0.001.txt

# %% [markdown]
# # EfficientNet-B0
# Here, we finetune EfficientNet-B0 with both TopK and RegTopK

# %%
from torchvision.models import efficientnet_b0
seeds = [42, 43, 44, 45, 46, 51, 52, 53, 54, 55]
k_frac = 0.01

# %%
# Prepare model for finetuning on ImageNette
def model_loader(model):
  # Freeze all layers
  for param in model.parameters():
      param.requires_grad = False

  # Replace classifier with trainable layer
  num_classes = len(train_dataset.classes)
  last_channel = model.classifier[1].in_features

  model.classifier[1] = torch.nn.Linear(last_channel, num_classes)

  # Only the final layer is trainable
  for param in model.classifier[1].parameters():
      param.requires_grad = True

  model = model.to(device)
  print(f"device is {device}")
  return model

# %% [markdown]
# #### TopK

# %%
max_accs_topK = []
min_losses_topK = []

last_accs_topK = []
last_losses_topK = []

for seed in seeds:
    print(f"\n==== Running with seed {seed} ====")

    # Set seed
    set_seed(seed)

    # Load and prepare model
    model = efficientnet_b0(weights=EfficientNet_B0_Weights)
    model = model_loader(model)

    # Train with TopK
    val_accs, val_losses = train_TopK(model, user_dataloaders, val_loader, epochs=8, lr=0.01, k_frac=k_frac)

    # Record max accuracy and min loss
    max_accs_topK.append(max(val_accs))
    min_losses_topK.append(min(val_losses))

    # Record last accuracy and loss
    last_accs_topK.append(val_accs[-1])
    last_losses_topK.append(val_losses[-1])

# Report results
print("\n===== Summary over seeds =====")
print(f"Max Val Accuracy: mean = {np.mean(max_accs_topK):.4f}, std = {np.std(max_accs_topK):.4f}")
print(f"Min Val Loss:     mean = {np.mean(min_losses_topK):.4f}, std = {np.std(min_losses_topK):.4f}")
print(f"Last-epoch Val Accuracy: mean = {np.mean(last_accs_topK):.4f}, std = {np.std(last_accs_topK):.4f}")
print(f"Last-epoch Val Loss:     mean = {np.mean(last_losses_topK):.4f}, std = {np.std(last_losses_topK):.4f}")
# Out:
# ==== Running with seed 42 ====
# device is mps
# /Users/alibereyhi/.venvs/py311/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/8 - Loss: 1.3258 - Val Acc: 0.8454
# Epoch 2/8 - Loss: 0.6927 - Val Acc: 0.8688
# Epoch 3/8 - Loss: 0.5707 - Val Acc: 0.8752
# Epoch 4/8 - Loss: 0.5118 - Val Acc: 0.8797
# Epoch 5/8 - Loss: 0.4692 - Val Acc: 0.8797
# Epoch 6/8 - Loss: 0.4389 - Val Acc: 0.8820
# Epoch 7/8 - Loss: 0.4323 - Val Acc: 0.8836
# Epoch 8/8 - Loss: 0.4222 - Val Acc: 0.8808
#
# ==== Running with seed 43 ====
# device is mps
# Epoch 1/8 - Loss: 1.3135 - Val Acc: 0.8527
# Epoch 2/8 - Loss: 0.6864 - Val Acc: 0.8711
# Epoch 3/8 - Loss: 0.5658 - Val Acc: 0.8716
# Epoch 4/8 - Loss: 0.5078 - Val Acc: 0.8782
# Epoch 5/8 - Loss: 0.4785 - Val Acc: 0.8797
# Epoch 6/8 - Loss: 0.4491 - Val Acc: 0.8777
# Epoch 7/8 - Loss: 0.4270 - Val Acc: 0.8780
# Epoch 8/8 - Loss: 0.4154 - Val Acc: 0.8782
#
# ==== Running with seed 44 ====
# device is mps
# Epoch 1/8 - Loss: 1.3434 - Val Acc: 0.8510
# Epoch 2/8 - Loss: 0.6963 - Val Acc: 0.8701
# Epoch 3/8 - Loss: 0.5753 - Val Acc: 0.8757
# Epoch 4/8 - Loss: 0.5014 - Val Acc: 0.8797
# Epoch 5/8 - Loss: 0.4689 - Val Acc: 0.8790
# Epoch 6/8 - Loss: 0.4468 - Val Acc: 0.8777
# Epoch 7/8 - Loss: 0.4328 - Val Acc: 0.8836
# Epoch 8/8 - Loss: 0.4073 - Val Acc: 0.8848
#
# ==== Running with seed 45 ====
# device is mps
# Epoch 1/8 - Loss: 1.3177 - Val Acc: 0.8609
# Epoch 2/8 - Loss: 0.6888 - Val Acc: 0.8734
# Epoch 3/8 - Loss: 0.5701 - Val Acc: 0.8775
# Epoch 4/8 - Loss: 0.5076 - Val Acc: 0.8803
# Epoch 5/8 - Loss: 0.4732 - Val Acc: 0.8810
# Epoch 6/8 - Loss: 0.4477 - Val Acc: 0.8820
# Epoch 7/8 - Loss: 0.4271 - Val Acc: 0.8869
# Epoch 8/8 - Loss: 0.4235 - Val Acc: 0.8828
#
# ==== Running with seed 46 ====
# device is mps
# Epoch 1/8 - Loss: 1.3290 - Val Acc: 0.8568
# Epoch 2/8 - Loss: 0.6974 - Val Acc: 0.8657
# Epoch 3/8 - Loss: 0.5699 - Val Acc: 0.8752
# Epoch 4/8 - Loss: 0.5116 - Val Acc: 0.8813
# Epoch 5/8 - Loss: 0.4740 - Val Acc: 0.8803
# Epoch 6/8 - Loss: 0.4419 - Val Acc: 0.8836
# Epoch 7/8 - Loss: 0.4328 - Val Acc: 0.8820
# Epoch 8/8 - Loss: 0.4191 - Val Acc: 0.8851
#
# ==== Running with seed 51 ====
# device is mps
# Epoch 1/8 - Loss: 1.3105 - Val Acc: 0.8527
# Epoch 2/8 - Loss: 0.6872 - Val Acc: 0.8639
# Epoch 3/8 - Loss: 0.5683 - Val Acc: 0.8780
# Epoch 4/8 - Loss: 0.4984 - Val Acc: 0.8764
# Epoch 5/8 - Loss: 0.4797 - Val Acc: 0.8797
# Epoch 6/8 - Loss: 0.4473 - Val Acc: 0.8800
# Epoch 7/8 - Loss: 0.4197 - Val Acc: 0.8810
# Epoch 8/8 - Loss: 0.4112 - Val Acc: 0.8838
#
# ==== Running with seed 52 ====
# device is mps
# Epoch 1/8 - Loss: 1.3275 - Val Acc: 0.8479
# Epoch 2/8 - Loss: 0.6857 - Val Acc: 0.8703
# Epoch 3/8 - Loss: 0.5581 - Val Acc: 0.8775
# Epoch 4/8 - Loss: 0.5029 - Val Acc: 0.8777
# Epoch 5/8 - Loss: 0.4716 - Val Acc: 0.8754
# Epoch 6/8 - Loss: 0.4399 - Val Acc: 0.8838
# Epoch 7/8 - Loss: 0.4230 - Val Acc: 0.8833
# Epoch 8/8 - Loss: 0.4102 - Val Acc: 0.8859
#
# ==== Running with seed 53 ====
# device is mps
# Epoch 1/8 - Loss: 1.3336 - Val Acc: 0.8504
# Epoch 2/8 - Loss: 0.7014 - Val Acc: 0.8734
# Epoch 3/8 - Loss: 0.5684 - Val Acc: 0.8785
# Epoch 4/8 - Loss: 0.5097 - Val Acc: 0.8797
# Epoch 5/8 - Loss: 0.4761 - Val Acc: 0.8792
# Epoch 6/8 - Loss: 0.4487 - Val Acc: 0.8785
# Epoch 7/8 - Loss: 0.4383 - Val Acc: 0.8831
# Epoch 8/8 - Loss: 0.4148 - Val Acc: 0.8800
#
# ==== Running with seed 54 ====
# device is mps
# Epoch 1/8 - Loss: 1.3219 - Val Acc: 0.8512
# Epoch 2/8 - Loss: 0.6913 - Val Acc: 0.8688
# Epoch 3/8 - Loss: 0.5720 - Val Acc: 0.8739
# Epoch 4/8 - Loss: 0.5037 - Val Acc: 0.8777
# Epoch 5/8 - Loss: 0.4720 - Val Acc: 0.8803
# Epoch 6/8 - Loss: 0.4499 - Val Acc: 0.8823
# Epoch 7/8 - Loss: 0.4280 - Val Acc: 0.8833
# Epoch 8/8 - Loss: 0.4093 - Val Acc: 0.8820
#
# ==== Running with seed 55 ====
# device is mps
# Epoch 1/8 - Loss: 1.2997 - Val Acc: 0.8566
# Epoch 2/8 - Loss: 0.6839 - Val Acc: 0.8721
# Epoch 3/8 - Loss: 0.5592 - Val Acc: 0.8782
# Epoch 4/8 - Loss: 0.5118 - Val Acc: 0.8813
# Epoch 5/8 - Loss: 0.4672 - Val Acc: 0.8780
# Epoch 6/8 - Loss: 0.4535 - Val Acc: 0.8785
# Epoch 7/8 - Loss: 0.4293 - Val Acc: 0.8833
# Epoch 8/8 - Loss: 0.4204 - Val Acc: 0.8861
#
# ===== Summary over seeds =====
# Max Val Accuracy: mean = 0.8842, std = 0.0019
# Min Val Loss:     mean = 0.4153, std = 0.0055
# Last-epoch Val Accuracy: mean = 0.8830, std = 0.0025
# Last-epoch Val Loss:     mean = 0.4153, std = 0.0055

# %%
# Folder and file name
# save_dir = "/content/drive/MyDrive/RegTopK/MobileNetV2"
save_dir = "EfficientNet-B0"
os.makedirs(save_dir, exist_ok=True)
filename = os.path.join(save_dir, f"TopK_{k_frac}.txt")

# Vectors
results = {
    "Max Val Accuracy": max_accs_topK,
    "Min Val Loss": min_losses_topK,
    "Last-epoch Val Accuracy": last_accs_topK,
    "Last-epoch Val Loss": last_losses_topK,
}

# Write to file
with open(filename, "w") as f:
    f.write(f"=== TopK Results Summary (EfficientNet-B0) for k={k_frac} ===\n\n")
    for name, values in results.items():
        mean = np.mean(values)
        std = np.std(values)
        f.write(f"{name}:\n")
        f.write(f"  Values: {np.round(values, 4).tolist()}\n")
        f.write(f"  Mean  : {mean:.4f}\n")
        f.write(f"  Std   : {std:.4f}\n\n")

print(f"Results saved to {filename}")
# Out:
# Results saved to EfficientNet-B0/TopK_0.01.txt

# %% [markdown]
# #### RegTopK

# %%
max_accs_regTopK = []
min_losses_regTopK = []

last_accs_regTopK = []
last_losses_regTopK = []

for seed in seeds:
    print(f"\n==== Running with seed {seed} ====")

    # Set seed
    set_seed(seed)

    # Load and prepare model
    model = efficientnet_b0(weights=EfficientNet_B0_Weights)
    model = model_loader(model)

    # Train with TopK
    val_accs, val_losses = train_regTopK(model, user_dataloaders, val_loader, epochs=8, lr=0.01, k_frac=k_frac)

    # Record max accuracy and min loss
    max_accs_regTopK.append(max(val_accs))
    min_losses_regTopK.append(min(val_losses))

    # Record last accuracy and loss
    last_accs_regTopK.append(val_accs[-1])
    last_losses_regTopK.append(val_losses[-1])

# Report results
print("\n===== Summary over seeds for RegTopK =====")
print(f"Max Val Accuracy: mean = {np.mean(max_accs_regTopK):.4f}, std = {np.std(max_accs_regTopK):.4f}")
print(f"Min Val Loss:     mean = {np.mean(min_losses_regTopK):.4f}, std = {np.std(min_losses_regTopK):.4f}")
print(f"Last-epoch Val Accuracy: mean = {np.mean(last_accs_regTopK):.4f}, std = {np.std(last_accs_regTopK):.4f}")
print(f"Last-epoch Val Loss:     mean = {np.mean(last_losses_regTopK):.4f}, std = {np.std(last_losses_regTopK):.4f}")
# Out:
# ==== Running with seed 42 ====
# device is mps
# Epoch 1/8 - Loss: 0.7892 - Val Acc: 0.8803
# Epoch 2/8 - Loss: 0.3916 - Val Acc: 0.8948
# Epoch 3/8 - Loss: 0.3513 - Val Acc: 0.8958
# Epoch 4/8 - Loss: 0.3381 - Val Acc: 0.8978
# Epoch 5/8 - Loss: 0.3050 - Val Acc: 0.8938
# Epoch 6/8 - Loss: 0.2880 - Val Acc: 0.8991
# Epoch 7/8 - Loss: 0.2924 - Val Acc: 0.8986
# Epoch 8/8 - Loss: 0.2895 - Val Acc: 0.8940
#
# ==== Running with seed 43 ====
# device is mps
# Epoch 1/8 - Loss: 0.7872 - Val Acc: 0.8833
# Epoch 2/8 - Loss: 0.3878 - Val Acc: 0.8955
# Epoch 3/8 - Loss: 0.3475 - Val Acc: 0.8907
# Epoch 4/8 - Loss: 0.3321 - Val Acc: 0.9009
# Epoch 5/8 - Loss: 0.3236 - Val Acc: 0.9006
# Epoch 6/8 - Loss: 0.3074 - Val Acc: 0.8989
# Epoch 7/8 - Loss: 0.2823 - Val Acc: 0.8963
# Epoch 8/8 - Loss: 0.2829 - Val Acc: 0.8963
#
# ==== Running with seed 44 ====
# device is mps
# Epoch 1/8 - Loss: 0.8071 - Val Acc: 0.8775
# Epoch 2/8 - Loss: 0.3873 - Val Acc: 0.8915
# Epoch 3/8 - Loss: 0.3556 - Val Acc: 0.8943
# Epoch 4/8 - Loss: 0.3146 - Val Acc: 0.8963
# Epoch 5/8 - Loss: 0.3082 - Val Acc: 0.9011
# Epoch 6/8 - Loss: 0.2928 - Val Acc: 0.8925
# Epoch 7/8 - Loss: 0.2838 - Val Acc: 0.9006
# Epoch 8/8 - Loss: 0.2723 - Val Acc: 0.8996
#
# ==== Running with seed 45 ====
# device is mps
# Epoch 1/8 - Loss: 0.7823 - Val Acc: 0.8876
# Epoch 2/8 - Loss: 0.3734 - Val Acc: 0.8932
# Epoch 3/8 - Loss: 0.3504 - Val Acc: 0.8971
# Epoch 4/8 - Loss: 0.3244 - Val Acc: 0.8938
# Epoch 5/8 - Loss: 0.3110 - Val Acc: 0.8973
# Epoch 6/8 - Loss: 0.3027 - Val Acc: 0.8999
# Epoch 7/8 - Loss: 0.2884 - Val Acc: 0.8981
# Epoch 8/8 - Loss: 0.2839 - Val Acc: 0.9006
#
# ==== Running with seed 46 ====
# device is mps
# Epoch 1/8 - Loss: 0.7951 - Val Acc: 0.8833
# Epoch 2/8 - Loss: 0.3927 - Val Acc: 0.8889
# Epoch 3/8 - Loss: 0.3509 - Val Acc: 0.8955
# Epoch 4/8 - Loss: 0.3287 - Val Acc: 0.8971
# Epoch 5/8 - Loss: 0.3095 - Val Acc: 0.8938
# Epoch 6/8 - Loss: 0.2919 - Val Acc: 0.8966
# Epoch 7/8 - Loss: 0.2933 - Val Acc: 0.8966
# Epoch 8/8 - Loss: 0.2765 - Val Acc: 0.9004
#
# ==== Running with seed 51 ====
# device is mps
# Epoch 1/8 - Loss: 0.7845 - Val Acc: 0.8833
# Epoch 2/8 - Loss: 0.3886 - Val Acc: 0.8864
# Epoch 3/8 - Loss: 0.3511 - Val Acc: 0.8950
# Epoch 4/8 - Loss: 0.3157 - Val Acc: 0.8953
# Epoch 5/8 - Loss: 0.3196 - Val Acc: 0.9006
# Epoch 6/8 - Loss: 0.2961 - Val Acc: 0.9001
# Epoch 7/8 - Loss: 0.2839 - Val Acc: 0.8917
# Epoch 8/8 - Loss: 0.2787 - Val Acc: 0.8976
#
# ==== Running with seed 52 ====
# device is mps
# Epoch 1/8 - Loss: 0.7927 - Val Acc: 0.8831
# Epoch 2/8 - Loss: 0.3724 - Val Acc: 0.8938
# Epoch 3/8 - Loss: 0.3425 - Val Acc: 0.9006
# Epoch 4/8 - Loss: 0.3254 - Val Acc: 0.8958
# Epoch 5/8 - Loss: 0.3095 - Val Acc: 0.8961
# Epoch 6/8 - Loss: 0.2853 - Val Acc: 0.8971
# Epoch 7/8 - Loss: 0.2827 - Val Acc: 0.8958
# Epoch 8/8 - Loss: 0.2768 - Val Acc: 0.8989
#
# ==== Running with seed 53 ====
# device is mps
# Epoch 1/8 - Loss: 0.7987 - Val Acc: 0.8851
# Epoch 2/8 - Loss: 0.3913 - Val Acc: 0.8940
# Epoch 3/8 - Loss: 0.3496 - Val Acc: 0.8971
# Epoch 4/8 - Loss: 0.3243 - Val Acc: 0.8950
# Epoch 5/8 - Loss: 0.3158 - Val Acc: 0.8958
# Epoch 6/8 - Loss: 0.2977 - Val Acc: 0.8935
# Epoch 7/8 - Loss: 0.2954 - Val Acc: 0.8973
# Epoch 8/8 - Loss: 0.2780 - Val Acc: 0.9004
#
# ==== Running with seed 54 ====
# device is mps
# Epoch 1/8 - Loss: 0.7905 - Val Acc: 0.8795
# Epoch 2/8 - Loss: 0.3834 - Val Acc: 0.8897
# Epoch 3/8 - Loss: 0.3529 - Val Acc: 0.8971
# Epoch 4/8 - Loss: 0.3180 - Val Acc: 0.8961
# Epoch 5/8 - Loss: 0.3084 - Val Acc: 0.8950
# Epoch 6/8 - Loss: 0.3022 - Val Acc: 0.8958
# Epoch 7/8 - Loss: 0.2851 - Val Acc: 0.8994
# Epoch 8/8 - Loss: 0.2805 - Val Acc: 0.8999
#
# ==== Running with seed 55 ====
# device is mps
# Epoch 1/8 - Loss: 0.7705 - Val Acc: 0.8894
# Epoch 2/8 - Loss: 0.3783 - Val Acc: 0.8958
# Epoch 3/8 - Loss: 0.3427 - Val Acc: 0.8935
# Epoch 4/8 - Loss: 0.3294 - Val Acc: 0.9014
# Epoch 5/8 - Loss: 0.3112 - Val Acc: 0.8950
# Epoch 6/8 - Loss: 0.3002 - Val Acc: 0.9001
# Epoch 7/8 - Loss: 0.2882 - Val Acc: 0.9001
# Epoch 8/8 - Loss: 0.2883 - Val Acc: 0.8986
#
# ===== Summary over seeds for RegTopK =====
# Max Val Accuracy: mean = 0.9005, std = 0.0006
# Min Val Loss:     mean = 0.2805, std = 0.0049
# Last-epoch Val Accuracy: mean = 0.8986, std = 0.0020
# Last-epoch Val Loss:     mean = 0.2807, std = 0.0051

# %%
# Folder and file name
save_dir = "EfficientNet-B0"
os.makedirs(save_dir, exist_ok=True)
filename = os.path.join(save_dir, f"RegTopK_{k_frac}.txt")

# Vectors
results = {
    "Max Val Accuracy": max_accs_regTopK,
    "Min Val Loss": min_losses_regTopK,
    "Last-epoch Val Accuracy": last_accs_regTopK,
    "Last-epoch Val Loss": last_losses_regTopK,
}

# Write to file
with open(filename, "w") as f:
    f.write(f"=== RegTopK Results Summary (EfficientNet-B0) for k={k_frac} ===\n\n")
    for name, values in results.items():
        mean = np.mean(values)
        std = np.std(values)
        f.write(f"{name}:\n")
        f.write(f"  Values: {np.round(values, 4).tolist()}\n")
        f.write(f"  Mean  : {mean:.4f}\n")
        f.write(f"  Std   : {std:.4f}\n\n")

print(f"Results saved to {filename}")
# Out:
# Results saved to EfficientNet-B0/RegTopK_0.01.txt

# %% [markdown]
# #### Check Statistical Significance
# We next compute p_values

# %%
from scipy.stats import ttest_rel, wilcoxon

# Paired t-test
t_stat, p_val_acc = ttest_rel(max_accs_regTopK, max_accs_topK)
print(f"Paired t-test on Accuracy: p = {p_val_acc:.5f}")

# Paired t-test
t_stat, p_val_loss = ttest_rel(min_losses_regTopK, min_losses_topK)
print(f"Paired t-test on loss: p = {p_val_loss:.5f}")

# Wilcoxon signed-rank test
w_stat, p_val_w_acc = wilcoxon(max_accs_regTopK, max_accs_topK)
print(f"Wilcoxon test on Accuracy: p = {p_val_w_acc:.5f}")

w_stat, p_val_w_loss = wilcoxon(min_losses_regTopK, min_losses_topK)
print(f"Wilcoxon test on loss: p = {p_val_w_loss:.5f}")
# Out:
# Paired t-test on Accuracy: p = 0.00000
# Paired t-test on loss: p = 0.00000
# Wilcoxon test on Accuracy: p = 0.00195
# Wilcoxon test on loss: p = 0.00195

# %%
save_dir = "EfficientNet-B0"
os.makedirs(save_dir, exist_ok=True)
filename = os.path.join(save_dir, f"p_values_{k_frac}.txt")

with open(filename, "w") as f:
    f.write(f"=== Statistical Significance (p-values) for k={k_frac} ===\n\n")
    f.write(f"Paired t-test on Accuracy: p = {p_val_acc:.5f}\n")
    f.write(f"Paired t-test on Loss:     p = {p_val_loss:.5f}\n")
    f.write(f"Wilcoxon test on Accuracy: p = {p_val_w_acc:.5f}\n")
    f.write(f"Wilcoxon test on Loss:     p = {p_val_w_loss:.5f}\n")

print(f"\n p-values saved to {filename}")
# Out:
#  p-values saved to EfficientNet-B0/p_values_0.01.txt

# %% [markdown]
# # ShuffleNetV2
# Here, we finetune ShuffleNetV2 with both TopK and RegTopK

# %%
from torchvision.models import shufflenet_v2_x1_0

seeds = [42, 43, 44, 45, 46, 51, 52, 53, 54, 55]
k_frac = 0.01

# %%
# Prepare model for finetuning on ImageNette
model = shufflenet_v2_x1_0(weights=ShuffleNet_V2_X1_0_Weights)

def model_loader(model):
  # Freeze all layers
  for param in model.parameters():
      param.requires_grad = False

  num_classes = len(train_dataset.classes)

  # Replace the final classification layer
  in_features = model.fc.in_features
  model.fc = torch.nn.Linear(in_features, num_classes)

  # Only the final layer is trainable
  for param in model.fc.parameters():
      param.requires_grad = True

  model = model.to(device)
  print(f"device is {device}")
  return model

# %% [markdown]
# #### TopK

# %%
max_accs_topK = []
min_losses_topK = []

last_accs_topK = []
last_losses_topK = []

for seed in seeds:
    print(f"\n==== Running with seed {seed} ====")

    # Set seed
    set_seed(seed)

    # Load and prepare model
    model = shufflenet_v2_x1_0(weights=ShuffleNet_V2_X1_0_Weights)
    model = model_loader(model)

    # Train with TopK
    val_accs, val_losses = train_TopK(model, user_dataloaders, val_loader, epochs=8, lr=0.01, k_frac=k_frac)

    # Record max accuracy and min loss
    max_accs_topK.append(max(val_accs))
    min_losses_topK.append(min(val_losses))

    # Record last accuracy and loss
    last_accs_topK.append(val_accs[-1])
    last_losses_topK.append(val_losses[-1])

# Report results
print("\n===== Summary over seeds =====")
print(f"Max Val Accuracy: mean = {np.mean(max_accs_topK):.4f}, std = {np.std(max_accs_topK):.4f}")
print(f"Min Val Loss:     mean = {np.mean(min_losses_topK):.4f}, std = {np.std(min_losses_topK):.4f}")
print(f"Last-epoch Val Accuracy: mean = {np.mean(last_accs_topK):.4f}, std = {np.std(last_accs_topK):.4f}")
print(f"Last-epoch Val Loss:     mean = {np.mean(last_losses_topK):.4f}, std = {np.std(last_losses_topK):.4f}")
# Out:
# ==== Running with seed 42 ====
# device is mps
# Epoch 1/8 - Loss: 2.2918 - Val Acc: 0.3954
# Epoch 2/8 - Loss: 2.2613 - Val Acc: 0.5159
# Epoch 3/8 - Loss: 2.2320 - Val Acc: 0.6117
# Epoch 4/8 - Loss: 2.2024 - Val Acc: 0.6978
# Epoch 5/8 - Loss: 2.1751 - Val Acc: 0.7152
# Epoch 6/8 - Loss: 2.1467 - Val Acc: 0.7294
# Epoch 7/8 - Loss: 2.1191 - Val Acc: 0.7396
# Epoch 8/8 - Loss: 2.0923 - Val Acc: 0.7518
#
# ==== Running with seed 43 ====
# device is mps
# Epoch 1/8 - Loss: 2.2890 - Val Acc: 0.3083
# Epoch 2/8 - Loss: 2.2590 - Val Acc: 0.5289
# Epoch 3/8 - Loss: 2.2291 - Val Acc: 0.6227
# Epoch 4/8 - Loss: 2.2003 - Val Acc: 0.6476
# Epoch 5/8 - Loss: 2.1713 - Val Acc: 0.6932
# Epoch 6/8 - Loss: 2.1431 - Val Acc: 0.7292
# Epoch 7/8 - Loss: 2.1165 - Val Acc: 0.7582
# Epoch 8/8 - Loss: 2.0892 - Val Acc: 0.7503
#
# ==== Running with seed 44 ====
# device is mps
# Epoch 1/8 - Loss: 2.2903 - Val Acc: 0.3786
# Epoch 2/8 - Loss: 2.2591 - Val Acc: 0.5664
# Epoch 3/8 - Loss: 2.2302 - Val Acc: 0.6813
# Epoch 4/8 - Loss: 2.2006 - Val Acc: 0.7284
# Epoch 5/8 - Loss: 2.1721 - Val Acc: 0.6917
# Epoch 6/8 - Loss: 2.1439 - Val Acc: 0.6874
# Epoch 7/8 - Loss: 2.1183 - Val Acc: 0.7269
# Epoch 8/8 - Loss: 2.0897 - Val Acc: 0.7350
#
# ==== Running with seed 45 ====
# device is mps
# Epoch 1/8 - Loss: 2.2913 - Val Acc: 0.3274
# Epoch 2/8 - Loss: 2.2604 - Val Acc: 0.4955
# Epoch 3/8 - Loss: 2.2317 - Val Acc: 0.6499
# Epoch 4/8 - Loss: 2.2014 - Val Acc: 0.6499
# Epoch 5/8 - Loss: 2.1738 - Val Acc: 0.6634
# Epoch 6/8 - Loss: 2.1454 - Val Acc: 0.7152
# Epoch 7/8 - Loss: 2.1175 - Val Acc: 0.7315
# Epoch 8/8 - Loss: 2.0927 - Val Acc: 0.7419
#
# ==== Running with seed 46 ====
# device is mps
# Epoch 1/8 - Loss: 2.2911 - Val Acc: 0.4140
# Epoch 2/8 - Loss: 2.2609 - Val Acc: 0.6028
# Epoch 3/8 - Loss: 2.2310 - Val Acc: 0.6754
# Epoch 4/8 - Loss: 2.2020 - Val Acc: 0.6795
# Epoch 5/8 - Loss: 2.1730 - Val Acc: 0.6994
# Epoch 6/8 - Loss: 2.1457 - Val Acc: 0.7371
# Epoch 7/8 - Loss: 2.1183 - Val Acc: 0.7246
# Epoch 8/8 - Loss: 2.0919 - Val Acc: 0.7406
#
# ==== Running with seed 51 ====
# device is mps
# Epoch 1/8 - Loss: 2.2892 - Val Acc: 0.4856
# Epoch 2/8 - Loss: 2.2585 - Val Acc: 0.5878
# Epoch 3/8 - Loss: 2.2292 - Val Acc: 0.5801
# Epoch 4/8 - Loss: 2.1995 - Val Acc: 0.6385
# Epoch 5/8 - Loss: 2.1709 - Val Acc: 0.7052
# Epoch 6/8 - Loss: 2.1434 - Val Acc: 0.7236
# Epoch 7/8 - Loss: 2.1164 - Val Acc: 0.7432
# Epoch 8/8 - Loss: 2.0903 - Val Acc: 0.7437
#
# ==== Running with seed 52 ====
# device is mps
# Epoch 1/8 - Loss: 2.2940 - Val Acc: 0.3704
# Epoch 2/8 - Loss: 2.2634 - Val Acc: 0.5406
# Epoch 3/8 - Loss: 2.2342 - Val Acc: 0.6166
# Epoch 4/8 - Loss: 2.2047 - Val Acc: 0.7108
# Epoch 5/8 - Loss: 2.1769 - Val Acc: 0.7083
# Epoch 6/8 - Loss: 2.1475 - Val Acc: 0.7302
# Epoch 7/8 - Loss: 2.1222 - Val Acc: 0.7116
# Epoch 8/8 - Loss: 2.0944 - Val Acc: 0.7090
#
# ==== Running with seed 53 ====
# device is mps
# Epoch 1/8 - Loss: 2.2897 - Val Acc: 0.3605
# Epoch 2/8 - Loss: 2.2591 - Val Acc: 0.5315
# Epoch 3/8 - Loss: 2.2297 - Val Acc: 0.6357
# Epoch 4/8 - Loss: 2.2004 - Val Acc: 0.6838
# Epoch 5/8 - Loss: 2.1717 - Val Acc: 0.6413
# Epoch 6/8 - Loss: 2.1438 - Val Acc: 0.7422
# Epoch 7/8 - Loss: 2.1162 - Val Acc: 0.7511
# Epoch 8/8 - Loss: 2.0886 - Val Acc: 0.7439
#
# ==== Running with seed 54 ====
# device is mps
# Epoch 1/8 - Loss: 2.2876 - Val Acc: 0.3330
# Epoch 2/8 - Loss: 2.2571 - Val Acc: 0.5366
# Epoch 3/8 - Loss: 2.2281 - Val Acc: 0.6331
# Epoch 4/8 - Loss: 2.1983 - Val Acc: 0.6604
# Epoch 5/8 - Loss: 2.1704 - Val Acc: 0.6861
# Epoch 6/8 - Loss: 2.1432 - Val Acc: 0.7231
# Epoch 7/8 - Loss: 2.1157 - Val Acc: 0.6976
# Epoch 8/8 - Loss: 2.0882 - Val Acc: 0.7215
#
# ==== Running with seed 55 ====
# device is mps
# Epoch 1/8 - Loss: 2.2879 - Val Acc: 0.3811
# Epoch 2/8 - Loss: 2.2578 - Val Acc: 0.5575
# Epoch 3/8 - Loss: 2.2285 - Val Acc: 0.6326
# Epoch 4/8 - Loss: 2.1985 - Val Acc: 0.6953
# Epoch 5/8 - Loss: 2.1708 - Val Acc: 0.7088
# Epoch 6/8 - Loss: 2.1416 - Val Acc: 0.7093
# Epoch 7/8 - Loss: 2.1147 - Val Acc: 0.7190
# Epoch 8/8 - Loss: 2.0881 - Val Acc: 0.7274
#
# ===== Summary over seeds =====
# Max Val Accuracy: mean = 0.7403, std = 0.0109
# Min Val Loss:     mean = 2.0905, std = 0.0021
# Last-epoch Val Accuracy: mean = 0.7365, std = 0.0128
# Last-epoch Val Loss:     mean = 2.0905, std = 0.0021

# %%
# Folder and file name
# save_dir = "/content/drive/MyDrive/RegTopK/MobileNetV2"
save_dir = "ShuffleNetV2"
os.makedirs(save_dir, exist_ok=True)
filename = os.path.join(save_dir, f"TopK_{k_frac}.txt")

# Vectors
results = {
    "Max Val Accuracy": max_accs_topK,
    "Min Val Loss": min_losses_topK,
    "Last-epoch Val Accuracy": last_accs_topK,
    "Last-epoch Val Loss": last_losses_topK,
}

# Write to file
with open(filename, "w") as f:
    f.write(f"=== TopK Results Summary (ShuffleNetV2) for k={k_frac} ===\n\n")
    for name, values in results.items():
        mean = np.mean(values)
        std = np.std(values)
        f.write(f"{name}:\n")
        f.write(f"  Values: {np.round(values, 4).tolist()}\n")
        f.write(f"  Mean  : {mean:.4f}\n")
        f.write(f"  Std   : {std:.4f}\n\n")

print(f"Results saved to {filename}")
# Out:
# Results saved to ShuffleNetV2/TopK_0.01.txt

# %% [markdown]
# #### RegTopK

# %%
max_accs_regTopK = []
min_losses_regTopK = []

last_accs_regTopK = []
last_losses_regTopK = []

for seed in seeds:
    print(f"\n==== Running with seed {seed} ====")

    # Set seed
    set_seed(seed)

    # Load and prepare model
    model = shufflenet_v2_x1_0(weights=ShuffleNet_V2_X1_0_Weights)
    model = model_loader(model)

    # Train with TopK
    val_accs, val_losses = train_regTopK(model, user_dataloaders, val_loader, epochs=8, lr=0.01, k_frac=k_frac)

    # Record max accuracy and min loss
    max_accs_regTopK.append(max(val_accs))
    min_losses_regTopK.append(min(val_losses))

    # Record last accuracy and loss
    last_accs_regTopK.append(val_accs[-1])
    last_losses_regTopK.append(val_losses[-1])

# Report results
print("\n===== Summary over seeds for RegTopK =====")
print(f"Max Val Accuracy: mean = {np.mean(max_accs_regTopK):.4f}, std = {np.std(max_accs_regTopK):.4f}")
print(f"Min Val Loss:     mean = {np.mean(min_losses_regTopK):.4f}, std = {np.std(min_losses_regTopK):.4f}")
print(f"Last-epoch Val Accuracy: mean = {np.mean(last_accs_regTopK):.4f}, std = {np.std(last_accs_regTopK):.4f}")
print(f"Last-epoch Val Loss:     mean = {np.mean(last_losses_regTopK):.4f}, std = {np.std(last_losses_regTopK):.4f}")
# Out:
# ==== Running with seed 42 ====
# device is mps
# Epoch 1/8 - Loss: 2.2565 - Val Acc: 0.6359
# Epoch 2/8 - Loss: 2.1213 - Val Acc: 0.7590
# Epoch 3/8 - Loss: 1.9920 - Val Acc: 0.7934
# Epoch 4/8 - Loss: 1.8716 - Val Acc: 0.8087
# Epoch 5/8 - Loss: 1.7682 - Val Acc: 0.8183
# Epoch 6/8 - Loss: 1.6708 - Val Acc: 0.8224
# Epoch 7/8 - Loss: 1.5821 - Val Acc: 0.8194
# Epoch 8/8 - Loss: 1.5040 - Val Acc: 0.8280
#
# ==== Running with seed 43 ====
# device is mps
# Epoch 1/8 - Loss: 2.2540 - Val Acc: 0.6199
# Epoch 2/8 - Loss: 2.1201 - Val Acc: 0.7603
# Epoch 3/8 - Loss: 1.9914 - Val Acc: 0.8043
# Epoch 4/8 - Loss: 1.8741 - Val Acc: 0.8056
# Epoch 5/8 - Loss: 1.7657 - Val Acc: 0.8143
# Epoch 6/8 - Loss: 1.6697 - Val Acc: 0.8145
# Epoch 7/8 - Loss: 1.5849 - Val Acc: 0.8224
# Epoch 8/8 - Loss: 1.5064 - Val Acc: 0.8275
#
# ==== Running with seed 44 ====
# device is mps
# Epoch 1/8 - Loss: 2.2552 - Val Acc: 0.6145
# Epoch 2/8 - Loss: 2.1201 - Val Acc: 0.7526
# Epoch 3/8 - Loss: 1.9925 - Val Acc: 0.7980
# Epoch 4/8 - Loss: 1.8731 - Val Acc: 0.8084
# Epoch 5/8 - Loss: 1.7668 - Val Acc: 0.8143
# Epoch 6/8 - Loss: 1.6699 - Val Acc: 0.8140
# Epoch 7/8 - Loss: 1.5865 - Val Acc: 0.8224
# Epoch 8/8 - Loss: 1.5039 - Val Acc: 0.8245
#
# ==== Running with seed 45 ====
# device is mps
# Epoch 1/8 - Loss: 2.2561 - Val Acc: 0.6390
# Epoch 2/8 - Loss: 2.1215 - Val Acc: 0.7684
# Epoch 3/8 - Loss: 1.9934 - Val Acc: 0.7967
# Epoch 4/8 - Loss: 1.8720 - Val Acc: 0.8069
# Epoch 5/8 - Loss: 1.7660 - Val Acc: 0.8138
# Epoch 6/8 - Loss: 1.6675 - Val Acc: 0.8255
# Epoch 7/8 - Loss: 1.5793 - Val Acc: 0.8265
# Epoch 8/8 - Loss: 1.5050 - Val Acc: 0.8288
#
# ==== Running with seed 46 ====
# device is mps
# Epoch 1/8 - Loss: 2.2561 - Val Acc: 0.6199
# Epoch 2/8 - Loss: 2.1223 - Val Acc: 0.7572
# Epoch 3/8 - Loss: 1.9927 - Val Acc: 0.7992
# Epoch 4/8 - Loss: 1.8752 - Val Acc: 0.8069
# Epoch 5/8 - Loss: 1.7657 - Val Acc: 0.8127
# Epoch 6/8 - Loss: 1.6707 - Val Acc: 0.8209
# Epoch 7/8 - Loss: 1.5850 - Val Acc: 0.8257
# Epoch 8/8 - Loss: 1.5078 - Val Acc: 0.8270
#
# ==== Running with seed 51 ====
# device is mps
# Epoch 1/8 - Loss: 2.2544 - Val Acc: 0.6410
# Epoch 2/8 - Loss: 2.1202 - Val Acc: 0.7595
# Epoch 3/8 - Loss: 1.9902 - Val Acc: 0.7946
# Epoch 4/8 - Loss: 1.8717 - Val Acc: 0.8084
# Epoch 5/8 - Loss: 1.7634 - Val Acc: 0.8163
# Epoch 6/8 - Loss: 1.6696 - Val Acc: 0.8194
# Epoch 7/8 - Loss: 1.5840 - Val Acc: 0.8209
# Epoch 8/8 - Loss: 1.5062 - Val Acc: 0.8262
#
# ==== Running with seed 52 ====
# device is mps
# Epoch 1/8 - Loss: 2.2587 - Val Acc: 0.6382
# Epoch 2/8 - Loss: 2.1229 - Val Acc: 0.7638
# Epoch 3/8 - Loss: 1.9938 - Val Acc: 0.7980
# Epoch 4/8 - Loss: 1.8750 - Val Acc: 0.8132
# Epoch 5/8 - Loss: 1.7693 - Val Acc: 0.8178
# Epoch 6/8 - Loss: 1.6697 - Val Acc: 0.8268
# Epoch 7/8 - Loss: 1.5871 - Val Acc: 0.8247
# Epoch 8/8 - Loss: 1.5066 - Val Acc: 0.8303
#
# ==== Running with seed 53 ====
# device is mps
# Epoch 1/8 - Loss: 2.2554 - Val Acc: 0.6759
# Epoch 2/8 - Loss: 2.1198 - Val Acc: 0.7704
# Epoch 3/8 - Loss: 1.9896 - Val Acc: 0.7969
# Epoch 4/8 - Loss: 1.8735 - Val Acc: 0.8082
# Epoch 5/8 - Loss: 1.7645 - Val Acc: 0.8211
# Epoch 6/8 - Loss: 1.6690 - Val Acc: 0.8209
# Epoch 7/8 - Loss: 1.5820 - Val Acc: 0.8227
# Epoch 8/8 - Loss: 1.5026 - Val Acc: 0.8308
#
# ==== Running with seed 54 ====
# device is mps
# Epoch 1/8 - Loss: 2.2529 - Val Acc: 0.6082
# Epoch 2/8 - Loss: 2.1183 - Val Acc: 0.7610
# Epoch 3/8 - Loss: 1.9901 - Val Acc: 0.7941
# Epoch 4/8 - Loss: 1.8707 - Val Acc: 0.8087
# Epoch 5/8 - Loss: 1.7662 - Val Acc: 0.8127
# Epoch 6/8 - Loss: 1.6711 - Val Acc: 0.8222
# Epoch 7/8 - Loss: 1.5835 - Val Acc: 0.8303
# Epoch 8/8 - Loss: 1.5042 - Val Acc: 0.8303
#
# ==== Running with seed 55 ====
# device is mps
# Epoch 1/8 - Loss: 2.2530 - Val Acc: 0.6005
# Epoch 2/8 - Loss: 2.1187 - Val Acc: 0.7546
# Epoch 3/8 - Loss: 1.9909 - Val Acc: 0.7878
# Epoch 4/8 - Loss: 1.8710 - Val Acc: 0.8054
# Epoch 5/8 - Loss: 1.7666 - Val Acc: 0.8135
# Epoch 6/8 - Loss: 1.6677 - Val Acc: 0.8204
# Epoch 7/8 - Loss: 1.5814 - Val Acc: 0.8250
# Epoch 8/8 - Loss: 1.5033 - Val Acc: 0.8275
#
# ===== Summary over seeds for RegTopK =====
# Max Val Accuracy: mean = 0.8281, std = 0.0019
# Min Val Loss:     mean = 1.5050, std = 0.0016
# Last-epoch Val Accuracy: mean = 0.8281, std = 0.0019
# Last-epoch Val Loss:     mean = 1.5050, std = 0.0016

# %%
# Folder and file name
save_dir = "ShuffleNetV2"
os.makedirs(save_dir, exist_ok=True)
filename = os.path.join(save_dir, f"RegTopK_{k_frac}.txt")

# Vectors
results = {
    "Max Val Accuracy": max_accs_regTopK,
    "Min Val Loss": min_losses_regTopK,
    "Last-epoch Val Accuracy": last_accs_regTopK,
    "Last-epoch Val Loss": last_losses_regTopK,
}

# Write to file
with open(filename, "w") as f:
    f.write(f"=== RegTopK Results Summary (ShuffleNetV2) for k={k_frac} ===\n\n")
    for name, values in results.items():
        mean = np.mean(values)
        std = np.std(values)
        f.write(f"{name}:\n")
        f.write(f"  Values: {np.round(values, 4).tolist()}\n")
        f.write(f"  Mean  : {mean:.4f}\n")
        f.write(f"  Std   : {std:.4f}\n\n")

print(f"Results saved to {filename}")
# Out:
# Results saved to ShuffleNetV2/RegTopK_0.01.txt

# %% [markdown]
# #### Check Statistical Significance
# We now compute p_values

# %%
from scipy.stats import ttest_rel, wilcoxon

# Paired t-test
t_stat, p_val_acc = ttest_rel(max_accs_regTopK, max_accs_topK)
print(f"Paired t-test on Accuracy: p = {p_val_acc:.5f}")

# Paired t-test
t_stat, p_val_loss = ttest_rel(min_losses_regTopK, min_losses_topK)
print(f"Paired t-test on loss: p = {p_val_loss:.5f}")

# Wilcoxon signed-rank test
w_stat, p_val_w_acc = wilcoxon(max_accs_regTopK, max_accs_topK)
print(f"Wilcoxon test on Accuracy: p = {p_val_w_acc:.5f}")

w_stat, p_val_w_loss = wilcoxon(min_losses_regTopK, min_losses_topK)
print(f"Wilcoxon test on loss: p = {p_val_w_loss:.5f}")
# Out:
# Paired t-test on Accuracy: p = 0.00000
# Paired t-test on loss: p = 0.00000
# Wilcoxon test on Accuracy: p = 0.00195
# Wilcoxon test on loss: p = 0.00195

# %%
save_dir = "ShuffleNetV2"
os.makedirs(save_dir, exist_ok=True)
filename = os.path.join(save_dir, f"p_values_{k_frac}.txt")

with open(filename, "w") as f:
    f.write(f"=== Statistical Significance (p-values) for k={k_frac} ===\n\n")
    f.write(f"Paired t-test on Accuracy: p = {p_val_acc:.5f}\n")
    f.write(f"Paired t-test on Loss:     p = {p_val_loss:.5f}\n")
    f.write(f"Wilcoxon test on Accuracy: p = {p_val_w_acc:.5f}\n")
    f.write(f"Wilcoxon test on Loss:     p = {p_val_w_loss:.5f}\n")

print(f"\n p-values saved to {filename}")
# Out:
#  p-values saved to ShuffleNetV2/p_values_0.01.txt

# %% [markdown]
# # SqueezeNet 1.0

# %%
from torchvision.models import squeezenet1_0

seeds = [42, 43, 44, 45, 46, 51, 52, 53, 54, 55]
k_frac = 0.01

# %%
# Prepare model for finetuning on ImageNette
model = squeezenet1_0(weights=SqueezeNet1_0_Weights)

def model_loader(model):
  # Freeze all layers
  for param in model.parameters():
      param.requires_grad = False

  num_classes = len(train_dataset.classes)

  # Replace the final conv layer to match num_classes
  model.classifier[1] = nn.Conv2d(512, num_classes, kernel_size=(1,1), stride=(1,1))


  # Only the final layer is trainable
  for param in model.classifier[1].parameters():
      param.requires_grad = True

  model = model.to(device)
  print(f"device is {device}")
  return model

# %% [markdown]
# #### TopK

# %%
max_accs_topK = []
min_losses_topK = []

last_accs_topK = []
last_losses_topK = []

for seed in seeds:
    print(f"\n==== Running with seed {seed} ====")

    # Set seed
    set_seed(seed)

    # Load and prepare model
    model = squeezenet1_0(weights=SqueezeNet1_0_Weights)
    model = model_loader(model)

    # Train with TopK
    val_accs, val_losses = train_TopK(model, user_dataloaders, val_loader, epochs=8, lr=0.01, k_frac=k_frac)

    # Record max accuracy and min loss
    max_accs_topK.append(max(val_accs))
    min_losses_topK.append(min(val_losses))

    # Record last accuracy and loss
    last_accs_topK.append(val_accs[-1])
    last_losses_topK.append(val_losses[-1])

# Report results
print("\n===== Summary over seeds =====")
print(f"Max Val Accuracy: mean = {np.mean(max_accs_topK):.4f}, std = {np.std(max_accs_topK):.4f}")
print(f"Min Val Loss:     mean = {np.mean(min_losses_topK):.4f}, std = {np.std(min_losses_topK):.4f}")
print(f"Last-epoch Val Accuracy: mean = {np.mean(last_accs_topK):.4f}, std = {np.std(last_accs_topK):.4f}")
print(f"Last-epoch Val Loss:     mean = {np.mean(last_losses_topK):.4f}, std = {np.std(last_losses_topK):.4f}")
# Out:
# ==== Running with seed 42 ====
# device is mps
# Epoch 1/8 - Loss: 1.0235 - Val Acc: 0.7776
# Epoch 2/8 - Loss: 0.7155 - Val Acc: 0.7980
# Epoch 3/8 - Loss: 0.6434 - Val Acc: 0.8130
# Epoch 4/8 - Loss: 0.6162 - Val Acc: 0.8222
# Epoch 5/8 - Loss: 0.5999 - Val Acc: 0.8313
# Epoch 6/8 - Loss: 0.5784 - Val Acc: 0.8280
# Epoch 7/8 - Loss: 0.5810 - Val Acc: 0.8176
# Epoch 8/8 - Loss: 0.5677 - Val Acc: 0.8293
#
# ==== Running with seed 43 ====
# device is mps
# Epoch 1/8 - Loss: 1.0610 - Val Acc: 0.7771
# Epoch 2/8 - Loss: 0.7150 - Val Acc: 0.8043
# Epoch 3/8 - Loss: 0.6746 - Val Acc: 0.8056
# Epoch 4/8 - Loss: 0.6510 - Val Acc: 0.8122
# Epoch 5/8 - Loss: 0.6008 - Val Acc: 0.8178
# Epoch 6/8 - Loss: 0.5991 - Val Acc: 0.7952
# Epoch 7/8 - Loss: 0.5845 - Val Acc: 0.8102
# Epoch 8/8 - Loss: 0.5674 - Val Acc: 0.8331
#
# ==== Running with seed 44 ====
# device is mps
# Epoch 1/8 - Loss: 1.1386 - Val Acc: 0.7753
# Epoch 2/8 - Loss: 0.7381 - Val Acc: 0.8025
# Epoch 3/8 - Loss: 0.6602 - Val Acc: 0.8158
# Epoch 4/8 - Loss: 0.6334 - Val Acc: 0.8211
# Epoch 5/8 - Loss: 0.6005 - Val Acc: 0.8115
# Epoch 6/8 - Loss: 0.5885 - Val Acc: 0.8168
# Epoch 7/8 - Loss: 0.5629 - Val Acc: 0.8255
# Epoch 8/8 - Loss: 0.5561 - Val Acc: 0.8232
#
# ==== Running with seed 45 ====
# device is mps
# Epoch 1/8 - Loss: 1.0135 - Val Acc: 0.7804
# Epoch 2/8 - Loss: 0.7429 - Val Acc: 0.8054
# Epoch 3/8 - Loss: 0.6806 - Val Acc: 0.8127
# Epoch 4/8 - Loss: 0.6365 - Val Acc: 0.8181
# Epoch 5/8 - Loss: 0.6090 - Val Acc: 0.8120
# Epoch 6/8 - Loss: 0.5916 - Val Acc: 0.8138
# Epoch 7/8 - Loss: 0.6013 - Val Acc: 0.8117
# Epoch 8/8 - Loss: 0.5770 - Val Acc: 0.8237
#
# ==== Running with seed 46 ====
# device is mps
# Epoch 1/8 - Loss: 0.9745 - Val Acc: 0.7730
# Epoch 2/8 - Loss: 0.7160 - Val Acc: 0.7936
# Epoch 3/8 - Loss: 0.6750 - Val Acc: 0.8092
# Epoch 4/8 - Loss: 0.6444 - Val Acc: 0.8059
# Epoch 5/8 - Loss: 0.6041 - Val Acc: 0.8232
# Epoch 6/8 - Loss: 0.5578 - Val Acc: 0.8270
# Epoch 7/8 - Loss: 0.5846 - Val Acc: 0.8219
# Epoch 8/8 - Loss: 0.5709 - Val Acc: 0.8232
#
# ==== Running with seed 51 ====
# device is mps
# Epoch 1/8 - Loss: 1.0443 - Val Acc: 0.7855
# Epoch 2/8 - Loss: 0.7001 - Val Acc: 0.8031
# Epoch 3/8 - Loss: 0.6550 - Val Acc: 0.8219
# Epoch 4/8 - Loss: 0.6172 - Val Acc: 0.8265
# Epoch 5/8 - Loss: 0.5994 - Val Acc: 0.8239
# Epoch 6/8 - Loss: 0.5837 - Val Acc: 0.8268
# Epoch 7/8 - Loss: 0.5969 - Val Acc: 0.8324
# Epoch 8/8 - Loss: 0.5732 - Val Acc: 0.8219
#
# ==== Running with seed 52 ====
# device is mps
# Epoch 1/8 - Loss: 0.9740 - Val Acc: 0.7977
# Epoch 2/8 - Loss: 0.6937 - Val Acc: 0.8008
# Epoch 3/8 - Loss: 0.6563 - Val Acc: 0.7980
# Epoch 4/8 - Loss: 0.6202 - Val Acc: 0.8166
# Epoch 5/8 - Loss: 0.6167 - Val Acc: 0.8104
# Epoch 6/8 - Loss: 0.5913 - Val Acc: 0.8173
# Epoch 7/8 - Loss: 0.5508 - Val Acc: 0.8186
# Epoch 8/8 - Loss: 0.5847 - Val Acc: 0.8199
#
# ==== Running with seed 53 ====
# device is mps
# Epoch 1/8 - Loss: 1.0107 - Val Acc: 0.7661
# Epoch 2/8 - Loss: 0.6942 - Val Acc: 0.8178
# Epoch 3/8 - Loss: 0.6279 - Val Acc: 0.8087
# Epoch 4/8 - Loss: 0.5847 - Val Acc: 0.8229
# Epoch 5/8 - Loss: 0.5819 - Val Acc: 0.8298
# Epoch 6/8 - Loss: 0.5523 - Val Acc: 0.8270
# Epoch 7/8 - Loss: 0.5608 - Val Acc: 0.8178
# Epoch 8/8 - Loss: 0.5516 - Val Acc: 0.8239
#
# ==== Running with seed 54 ====
# device is mps
# Epoch 1/8 - Loss: 1.0210 - Val Acc: 0.7817
# Epoch 2/8 - Loss: 0.7232 - Val Acc: 0.8031
# Epoch 3/8 - Loss: 0.6588 - Val Acc: 0.8145
# Epoch 4/8 - Loss: 0.6415 - Val Acc: 0.8122
# Epoch 5/8 - Loss: 0.6243 - Val Acc: 0.8038
# Epoch 6/8 - Loss: 0.6208 - Val Acc: 0.8209
# Epoch 7/8 - Loss: 0.5799 - Val Acc: 0.8257
# Epoch 8/8 - Loss: 0.5679 - Val Acc: 0.8222
#
# ==== Running with seed 55 ====
# device is mps
# Epoch 1/8 - Loss: 0.9834 - Val Acc: 0.7855
# Epoch 2/8 - Loss: 0.7106 - Val Acc: 0.8056
# Epoch 3/8 - Loss: 0.6560 - Val Acc: 0.8201
# Epoch 4/8 - Loss: 0.6297 - Val Acc: 0.8250
# Epoch 5/8 - Loss: 0.6063 - Val Acc: 0.8209
# Epoch 6/8 - Loss: 0.5885 - Val Acc: 0.8148
# Epoch 7/8 - Loss: 0.5783 - Val Acc: 0.8140
# Epoch 8/8 - Loss: 0.5696 - Val Acc: 0.8178
#
# ===== Summary over seeds =====
# Max Val Accuracy: mean = 0.8273, std = 0.0040
# Min Val Loss:     mean = 0.5639, std = 0.0087
# Last-epoch Val Accuracy: mean = 0.8238, std = 0.0042
# Last-epoch Val Loss:     mean = 0.5686, std = 0.0090

# %%
# Folder and file name
save_dir = "SqueezeNet1.0"
os.makedirs(save_dir, exist_ok=True)
filename = os.path.join(save_dir, f"TopK_{k_frac}.txt")

# Vectors
results = {
    "Max Val Accuracy": max_accs_topK,
    "Min Val Loss": min_losses_topK,
    "Last-epoch Val Accuracy": last_accs_topK,
    "Last-epoch Val Loss": last_losses_topK,
}

# Write to file
with open(filename, "w") as f:
    f.write(f"=== TopK Results Summary (SqueezeNet1.0) for k={k_frac} ===\n\n")
    for name, values in results.items():
        mean = np.mean(values)
        std = np.std(values)
        f.write(f"{name}:\n")
        f.write(f"  Values: {np.round(values, 4).tolist()}\n")
        f.write(f"  Mean  : {mean:.4f}\n")
        f.write(f"  Std   : {std:.4f}\n\n")

print(f"Results saved to {filename}")
# Out:
# Results saved to SqueezeNet1.0/TopK_0.01.txt

# %% [markdown]
# #### RegTopK

# %%
max_accs_regTopK = []
min_losses_regTopK = []

last_accs_regTopK = []
last_losses_regTopK = []

for seed in seeds:
    print(f"\n==== Running with seed {seed} ====")

    # Set seed
    set_seed(seed)

    # Load and prepare model
    model = squeezenet1_0(weights=SqueezeNet1_0_Weights)
    model = model_loader(model)

    # Train with TopK
    val_accs, val_losses = train_regTopK(model, user_dataloaders, val_loader, epochs=8, lr=0.01, k_frac=k_frac)

    # Record max accuracy and min loss
    max_accs_regTopK.append(max(val_accs))
    min_losses_regTopK.append(min(val_losses))

    # Record last accuracy and loss
    last_accs_regTopK.append(val_accs[-1])
    last_losses_regTopK.append(val_losses[-1])

# Report results
print("\n===== Summary over seeds for RegTopK =====")
print(f"Max Val Accuracy: mean = {np.mean(max_accs_regTopK):.4f}, std = {np.std(max_accs_regTopK):.4f}")
print(f"Min Val Loss:     mean = {np.mean(min_losses_regTopK):.4f}, std = {np.std(min_losses_regTopK):.4f}")
print(f"Last-epoch Val Accuracy: mean = {np.mean(last_accs_regTopK):.4f}, std = {np.std(last_accs_regTopK):.4f}")
print(f"Last-epoch Val Loss:     mean = {np.mean(last_losses_regTopK):.4f}, std = {np.std(last_losses_regTopK):.4f}")
# Out:
# ==== Running with seed 42 ====
# device is mps
# Epoch 1/8 - Loss: 0.8963 - Val Acc: 0.8275
# Epoch 2/8 - Loss: 0.5544 - Val Acc: 0.8487
# Epoch 3/8 - Loss: 0.4661 - Val Acc: 0.8637
# Epoch 4/8 - Loss: 0.4333 - Val Acc: 0.8690
# Epoch 5/8 - Loss: 0.4351 - Val Acc: 0.8665
# Epoch 6/8 - Loss: 0.4246 - Val Acc: 0.8517
# Epoch 7/8 - Loss: 0.4123 - Val Acc: 0.8502
# Epoch 8/8 - Loss: 0.3796 - Val Acc: 0.8800
#
# ==== Running with seed 43 ====
# device is mps
# Epoch 1/8 - Loss: 0.9970 - Val Acc: 0.8288
# Epoch 2/8 - Loss: 0.5567 - Val Acc: 0.8324
# Epoch 3/8 - Loss: 0.4917 - Val Acc: 0.8573
# Epoch 4/8 - Loss: 0.4548 - Val Acc: 0.8507
# Epoch 5/8 - Loss: 0.4117 - Val Acc: 0.8624
# Epoch 6/8 - Loss: 0.4176 - Val Acc: 0.8642
# Epoch 7/8 - Loss: 0.4034 - Val Acc: 0.8581
# Epoch 8/8 - Loss: 0.3914 - Val Acc: 0.8609
#
# ==== Running with seed 44 ====
# device is mps
# Epoch 1/8 - Loss: 1.0053 - Val Acc: 0.8181
# Epoch 2/8 - Loss: 0.5816 - Val Acc: 0.8464
# Epoch 3/8 - Loss: 0.4902 - Val Acc: 0.8591
# Epoch 4/8 - Loss: 0.4559 - Val Acc: 0.8683
# Epoch 5/8 - Loss: 0.4188 - Val Acc: 0.8632
# Epoch 6/8 - Loss: 0.4210 - Val Acc: 0.8561
# Epoch 7/8 - Loss: 0.4131 - Val Acc: 0.8601
# Epoch 8/8 - Loss: 0.3821 - Val Acc: 0.8655
#
# ==== Running with seed 45 ====
# device is mps
# Epoch 1/8 - Loss: 0.9748 - Val Acc: 0.8242
# Epoch 2/8 - Loss: 0.5621 - Val Acc: 0.8466
# Epoch 3/8 - Loss: 0.5064 - Val Acc: 0.8571
# Epoch 4/8 - Loss: 0.4562 - Val Acc: 0.8713
# Epoch 5/8 - Loss: 0.4311 - Val Acc: 0.8606
# Epoch 6/8 - Loss: 0.4369 - Val Acc: 0.8655
# Epoch 7/8 - Loss: 0.4090 - Val Acc: 0.8606
# Epoch 8/8 - Loss: 0.3866 - Val Acc: 0.8716
#
# ==== Running with seed 46 ====
# device is mps
# Epoch 1/8 - Loss: 1.0388 - Val Acc: 0.8219
# Epoch 2/8 - Loss: 0.5605 - Val Acc: 0.8464
# Epoch 3/8 - Loss: 0.4894 - Val Acc: 0.8535
# Epoch 4/8 - Loss: 0.4427 - Val Acc: 0.8606
# Epoch 5/8 - Loss: 0.4330 - Val Acc: 0.8614
# Epoch 6/8 - Loss: 0.4008 - Val Acc: 0.8629
# Epoch 7/8 - Loss: 0.3981 - Val Acc: 0.8678
# Epoch 8/8 - Loss: 0.4075 - Val Acc: 0.8782
#
# ==== Running with seed 51 ====
# device is mps
# Epoch 1/8 - Loss: 1.0476 - Val Acc: 0.8110
# Epoch 2/8 - Loss: 0.5766 - Val Acc: 0.8382
# Epoch 3/8 - Loss: 0.5011 - Val Acc: 0.8441
# Epoch 4/8 - Loss: 0.4627 - Val Acc: 0.8545
# Epoch 5/8 - Loss: 0.4292 - Val Acc: 0.8517
# Epoch 6/8 - Loss: 0.3973 - Val Acc: 0.8685
# Epoch 7/8 - Loss: 0.3939 - Val Acc: 0.8706
# Epoch 8/8 - Loss: 0.3774 - Val Acc: 0.8576
#
# ==== Running with seed 52 ====
# device is mps
# Epoch 1/8 - Loss: 0.9894 - Val Acc: 0.8278
# Epoch 2/8 - Loss: 0.5504 - Val Acc: 0.8408
# Epoch 3/8 - Loss: 0.4765 - Val Acc: 0.8543
# Epoch 4/8 - Loss: 0.4385 - Val Acc: 0.8614
# Epoch 5/8 - Loss: 0.4285 - Val Acc: 0.8690
# Epoch 6/8 - Loss: 0.4158 - Val Acc: 0.8698
# Epoch 7/8 - Loss: 0.3982 - Val Acc: 0.8662
# Epoch 8/8 - Loss: 0.4006 - Val Acc: 0.8685
#
# ==== Running with seed 53 ====
# device is mps
# Epoch 1/8 - Loss: 0.9401 - Val Acc: 0.8239
# Epoch 2/8 - Loss: 0.5528 - Val Acc: 0.8441
# Epoch 3/8 - Loss: 0.4886 - Val Acc: 0.8545
# Epoch 4/8 - Loss: 0.4711 - Val Acc: 0.8555
# Epoch 5/8 - Loss: 0.4171 - Val Acc: 0.8693
# Epoch 6/8 - Loss: 0.4123 - Val Acc: 0.8668
# Epoch 7/8 - Loss: 0.3966 - Val Acc: 0.8642
# Epoch 8/8 - Loss: 0.3851 - Val Acc: 0.8502
#
# ==== Running with seed 54 ====
# device is mps
# Epoch 1/8 - Loss: 1.0304 - Val Acc: 0.8140
# Epoch 2/8 - Loss: 0.6060 - Val Acc: 0.8403
# Epoch 3/8 - Loss: 0.5025 - Val Acc: 0.8494
# Epoch 4/8 - Loss: 0.4617 - Val Acc: 0.8589
# Epoch 5/8 - Loss: 0.4398 - Val Acc: 0.8550
# Epoch 6/8 - Loss: 0.4195 - Val Acc: 0.8744
# Epoch 7/8 - Loss: 0.3942 - Val Acc: 0.8690
# Epoch 8/8 - Loss: 0.3905 - Val Acc: 0.8685
#
# ==== Running with seed 55 ====
# device is mps
# Epoch 1/8 - Loss: 0.9488 - Val Acc: 0.8326
# Epoch 2/8 - Loss: 0.5410 - Val Acc: 0.8532
# Epoch 3/8 - Loss: 0.4769 - Val Acc: 0.8540
# Epoch 4/8 - Loss: 0.4568 - Val Acc: 0.8543
# Epoch 5/8 - Loss: 0.4418 - Val Acc: 0.8543
# Epoch 6/8 - Loss: 0.4145 - Val Acc: 0.8566
# Epoch 7/8 - Loss: 0.3943 - Val Acc: 0.8680
# Epoch 8/8 - Loss: 0.3783 - Val Acc: 0.8749
#
# ===== Summary over seeds for RegTopK =====
# Max Val Accuracy: mean = 0.8721, std = 0.0045
# Min Val Loss:     mean = 0.3867, std = 0.0073
# Last-epoch Val Accuracy: mean = 0.8676, std = 0.0089
# Last-epoch Val Loss:     mean = 0.3879, std = 0.0094

# %%
# Folder and file name
save_dir = "SqueezeNet1.0"
os.makedirs(save_dir, exist_ok=True)
filename = os.path.join(save_dir, f"RegTopK_{k_frac}.txt")

# Vectors
results = {
    "Max Val Accuracy": max_accs_regTopK,
    "Min Val Loss": min_losses_regTopK,
    "Last-epoch Val Accuracy": last_accs_regTopK,
    "Last-epoch Val Loss": last_losses_regTopK,
}

# Write to file
with open(filename, "w") as f:
    f.write(f"=== RegTopK Results Summary (SqueezeNet1.0) for k={k_frac} ===\n\n")
    for name, values in results.items():
        mean = np.mean(values)
        std = np.std(values)
        f.write(f"{name}:\n")
        f.write(f"  Values: {np.round(values, 4).tolist()}\n")
        f.write(f"  Mean  : {mean:.4f}\n")
        f.write(f"  Std   : {std:.4f}\n\n")

print(f"Results saved to {filename}")
# Out:
# Results saved to SqueezeNet1.0/RegTopK_0.01.txt

# %% [markdown]
# #### Checking Statistical Significance

# %%
from scipy.stats import ttest_rel, wilcoxon

# Paired t-test
t_stat, p_val_acc = ttest_rel(max_accs_regTopK, max_accs_topK)
print(f"Paired t-test on Accuracy: p = {p_val_acc:.5f}")

# Paired t-test
t_stat, p_val_loss = ttest_rel(min_losses_regTopK, min_losses_topK)
print(f"Paired t-test on loss: p = {p_val_loss:.5f}")

# Wilcoxon signed-rank test
w_stat, p_val_w_acc = wilcoxon(max_accs_regTopK, max_accs_topK)
print(f"Wilcoxon test on Accuracy: p = {p_val_w_acc:.5f}")

w_stat, p_val_w_loss = wilcoxon(min_losses_regTopK, min_losses_topK)
print(f"Wilcoxon test on loss: p = {p_val_w_loss:.5f}")
# Out:
# Paired t-test on Accuracy: p = 0.00000
# Paired t-test on loss: p = 0.00000
# Wilcoxon test on Accuracy: p = 0.00195
# Wilcoxon test on loss: p = 0.00195

# %%
save_dir = "SqueezeNet1.0"
os.makedirs(save_dir, exist_ok=True)
filename = os.path.join(save_dir, f"p_values_{k_frac}.txt")

with open(filename, "w") as f:
    f.write(f"=== Statistical Significance (p-values) for k={k_frac} ===\n\n")
    f.write(f"Paired t-test on Accuracy: p = {p_val_acc:.5f}\n")
    f.write(f"Paired t-test on Loss:     p = {p_val_loss:.5f}\n")
    f.write(f"Wilcoxon test on Accuracy: p = {p_val_w_acc:.5f}\n")
    f.write(f"Wilcoxon test on Loss:     p = {p_val_w_loss:.5f}\n")

print(f"\n p-values saved to {filename}")
# Out:
#  p-values saved to SqueezeNet1.0/p_values_0.01.txt

# %% [markdown]
# # ResNet-152

# %%
from torchvision.models import resnet152

seeds = [42, 43, 44, 45, 46, 51, 52, 53, 54, 55]
k_frac = 0.01

# %%
# Prepare model for finetuning on ImageNette
model = resnet152(weights=ResNet152_Weights)

def model_loader(model):
  # Freeze all layers
  for param in model.parameters():
      param.requires_grad = False

  num_classes = len(train_dataset.classes)

  # Replace the final classification layer
  in_features = model.fc.in_features
  model.fc = torch.nn.Linear(in_features, num_classes)

  # Only the final layer is trainable
  for param in model.fc.parameters():
      param.requires_grad = True

  model = model.to(device)
  print(f"device is {device}")
  return model

# %% [markdown]
# #### TopK

# %%
max_accs_topK = []
min_losses_topK = []

last_accs_topK = []
last_losses_topK = []

for seed in seeds:
    print(f"\n==== Running with seed {seed} ====")

    # Set seed
    set_seed(seed)

    # Load and prepare model
    model = resnet152(weights=ResNet152_Weights)
    model = model_loader(model)

    # Train with TopK
    val_accs, val_losses = train_TopK(model, user_dataloaders, val_loader, epochs=8, lr=0.01, k_frac=k_frac)

    # Record max accuracy and min loss
    max_accs_topK.append(max(val_accs))
    min_losses_topK.append(min(val_losses))

    # Record last accuracy and loss
    last_accs_topK.append(val_accs[-1])
    last_losses_topK.append(val_losses[-1])

# Report results
print("\n===== Summary over seeds =====")
print(f"Max Val Accuracy: mean = {np.mean(max_accs_topK):.4f}, std = {np.std(max_accs_topK):.4f}")
print(f"Min Val Loss:     mean = {np.mean(min_losses_topK):.4f}, std = {np.std(min_losses_topK):.4f}")
print(f"Last-epoch Val Accuracy: mean = {np.mean(last_accs_topK):.4f}, std = {np.std(last_accs_topK):.4f}")
print(f"Last-epoch Val Loss:     mean = {np.mean(last_losses_topK):.4f}, std = {np.std(last_losses_topK):.4f}")
# Out:
# ==== Running with seed 42 ====
# device is mps
# Epoch 1/8 - Loss: 0.4621 - Val Acc: 0.9325
# Epoch 2/8 - Loss: 0.2172 - Val Acc: 0.9330
# Epoch 3/8 - Loss: 0.1971 - Val Acc: 0.9399
# Epoch 4/8 - Loss: 0.1765 - Val Acc: 0.9409
# Epoch 5/8 - Loss: 0.1697 - Val Acc: 0.9389
# Epoch 6/8 - Loss: 0.1591 - Val Acc: 0.9457
# Epoch 7/8 - Loss: 0.1505 - Val Acc: 0.9442
# Epoch 8/8 - Loss: 0.1465 - Val Acc: 0.9391
#
# ==== Running with seed 43 ====
# device is mps
# Epoch 1/8 - Loss: 0.4572 - Val Acc: 0.9332
# Epoch 2/8 - Loss: 0.2241 - Val Acc: 0.9401
# Epoch 3/8 - Loss: 0.1875 - Val Acc: 0.9391
# Epoch 4/8 - Loss: 0.1746 - Val Acc: 0.9422
# Epoch 5/8 - Loss: 0.1631 - Val Acc: 0.9406
# Epoch 6/8 - Loss: 0.1574 - Val Acc: 0.9417
# Epoch 7/8 - Loss: 0.1491 - Val Acc: 0.9376
# Epoch 8/8 - Loss: 0.1419 - Val Acc: 0.9409
#
# ==== Running with seed 44 ====
# device is mps
# Epoch 1/8 - Loss: 0.4644 - Val Acc: 0.9338
# Epoch 2/8 - Loss: 0.2317 - Val Acc: 0.9383
# Epoch 3/8 - Loss: 0.2024 - Val Acc: 0.9409
# Epoch 4/8 - Loss: 0.1826 - Val Acc: 0.9411
# Epoch 5/8 - Loss: 0.1667 - Val Acc: 0.9406
# Epoch 6/8 - Loss: 0.1579 - Val Acc: 0.9376
# Epoch 7/8 - Loss: 0.1530 - Val Acc: 0.9399
# Epoch 8/8 - Loss: 0.1498 - Val Acc: 0.9366
#
# ==== Running with seed 45 ====
# device is mps
# Epoch 1/8 - Loss: 0.4720 - Val Acc: 0.9355
# Epoch 2/8 - Loss: 0.2225 - Val Acc: 0.9391
# Epoch 3/8 - Loss: 0.1936 - Val Acc: 0.9396
# Epoch 4/8 - Loss: 0.1786 - Val Acc: 0.9399
# Epoch 5/8 - Loss: 0.1664 - Val Acc: 0.9401
# Epoch 6/8 - Loss: 0.1570 - Val Acc: 0.9437
# Epoch 7/8 - Loss: 0.1517 - Val Acc: 0.9406
# Epoch 8/8 - Loss: 0.1537 - Val Acc: 0.9417
#
# ==== Running with seed 46 ====
# device is mps
# Epoch 1/8 - Loss: 0.4634 - Val Acc: 0.9353
# Epoch 2/8 - Loss: 0.2258 - Val Acc: 0.9343
# Epoch 3/8 - Loss: 0.1929 - Val Acc: 0.9427
# Epoch 4/8 - Loss: 0.1852 - Val Acc: 0.9406
# Epoch 5/8 - Loss: 0.1638 - Val Acc: 0.9417
# Epoch 6/8 - Loss: 0.1651 - Val Acc: 0.9399
# Epoch 7/8 - Loss: 0.1538 - Val Acc: 0.9401
# Epoch 8/8 - Loss: 0.1496 - Val Acc: 0.9406
#
# ==== Running with seed 51 ====
# device is mps
# Epoch 1/8 - Loss: 0.4610 - Val Acc: 0.9320
# Epoch 2/8 - Loss: 0.2244 - Val Acc: 0.9373
# Epoch 3/8 - Loss: 0.1955 - Val Acc: 0.9383
# Epoch 4/8 - Loss: 0.1799 - Val Acc: 0.9383
# Epoch 5/8 - Loss: 0.1732 - Val Acc: 0.9389
# Epoch 6/8 - Loss: 0.1618 - Val Acc: 0.9404
# Epoch 7/8 - Loss: 0.1585 - Val Acc: 0.9396
# Epoch 8/8 - Loss: 0.1510 - Val Acc: 0.9383
#
# ==== Running with seed 52 ====
# device is mps
# Epoch 1/8 - Loss: 0.4603 - Val Acc: 0.9332
# Epoch 2/8 - Loss: 0.2188 - Val Acc: 0.9371
# Epoch 3/8 - Loss: 0.1938 - Val Acc: 0.9414
# Epoch 4/8 - Loss: 0.1803 - Val Acc: 0.9368
# Epoch 5/8 - Loss: 0.1684 - Val Acc: 0.9378
# Epoch 6/8 - Loss: 0.1574 - Val Acc: 0.9445
# Epoch 7/8 - Loss: 0.1546 - Val Acc: 0.9386
# Epoch 8/8 - Loss: 0.1506 - Val Acc: 0.9399
#
# ==== Running with seed 53 ====
# device is mps
# Epoch 1/8 - Loss: 0.4597 - Val Acc: 0.9348
# Epoch 2/8 - Loss: 0.2257 - Val Acc: 0.9409
# Epoch 3/8 - Loss: 0.1954 - Val Acc: 0.9389
# Epoch 4/8 - Loss: 0.1769 - Val Acc: 0.9411
# Epoch 5/8 - Loss: 0.1732 - Val Acc: 0.9404
# Epoch 6/8 - Loss: 0.1639 - Val Acc: 0.9368
# Epoch 7/8 - Loss: 0.1547 - Val Acc: 0.9366
# Epoch 8/8 - Loss: 0.1438 - Val Acc: 0.9381
#
# ==== Running with seed 54 ====
# device is mps
# Epoch 1/8 - Loss: 0.4588 - Val Acc: 0.9396
# Epoch 2/8 - Loss: 0.2239 - Val Acc: 0.9401
# Epoch 3/8 - Loss: 0.1985 - Val Acc: 0.9424
# Epoch 4/8 - Loss: 0.1823 - Val Acc: 0.9429
# Epoch 5/8 - Loss: 0.1694 - Val Acc: 0.9450
# Epoch 6/8 - Loss: 0.1578 - Val Acc: 0.9447
# Epoch 7/8 - Loss: 0.1523 - Val Acc: 0.9391
# Epoch 8/8 - Loss: 0.1461 - Val Acc: 0.9424
#
# ==== Running with seed 55 ====
# device is mps
# Epoch 1/8 - Loss: 0.4620 - Val Acc: 0.9358
# Epoch 2/8 - Loss: 0.2216 - Val Acc: 0.9378
# Epoch 3/8 - Loss: 0.1911 - Val Acc: 0.9371
# Epoch 4/8 - Loss: 0.1767 - Val Acc: 0.9429
# Epoch 5/8 - Loss: 0.1630 - Val Acc: 0.9437
# Epoch 6/8 - Loss: 0.1601 - Val Acc: 0.9396
# Epoch 7/8 - Loss: 0.1494 - Val Acc: 0.9414
# Epoch 8/8 - Loss: 0.1466 - Val Acc: 0.9419
#
# ===== Summary over seeds =====
# Max Val Accuracy: mean = 0.9430, std = 0.0017
# Min Val Loss:     mean = 0.1478, std = 0.0031
# Last-epoch Val Accuracy: mean = 0.9399, std = 0.0018
# Last-epoch Val Loss:     mean = 0.1480, std = 0.0034

# %%
# Folder and file name
save_dir = "ResNet152"
os.makedirs(save_dir, exist_ok=True)
filename = os.path.join(save_dir, f"TopK_{k_frac}.txt")

# Vectors
results = {
    "Max Val Accuracy": max_accs_topK,
    "Min Val Loss": min_losses_topK,
    "Last-epoch Val Accuracy": last_accs_topK,
    "Last-epoch Val Loss": last_losses_topK,
}

# Write to file
with open(filename, "w") as f:
    f.write(f"=== TopK Results Summary (ResNet152) for k={k_frac} ===\n\n")
    for name, values in results.items():
        mean = np.mean(values)
        std = np.std(values)
        f.write(f"{name}:\n")
        f.write(f"  Values: {np.round(values, 4).tolist()}\n")
        f.write(f"  Mean  : {mean:.4f}\n")
        f.write(f"  Std   : {std:.4f}\n\n")

print(f"Results saved to {filename}")
# Out:
# Results saved to ResNet152/TopK_0.01.txt

# %% [markdown]
# #### RegTopK

# %%
max_accs_regTopK = []
min_losses_regTopK = []

last_accs_regTopK = []
last_losses_regTopK = []

for seed in seeds:
    print(f"\n==== Running with seed {seed} ====")

    # Set seed
    set_seed(seed)

    # Load and prepare model
    model = resnet152(weights=ResNet152_Weights)
    model = model_loader(model)

    # Train with TopK
    val_accs, val_losses = train_regTopK(model, user_dataloaders, val_loader, epochs=8, lr=0.01, k_frac=k_frac)

    # Record max accuracy and min loss
    max_accs_regTopK.append(max(val_accs))
    min_losses_regTopK.append(min(val_losses))

    # Record last accuracy and loss
    last_accs_regTopK.append(val_accs[-1])
    last_losses_regTopK.append(val_losses[-1])

# Report results
print("\n===== Summary over seeds for RegTopK =====")
print(f"Max Val Accuracy: mean = {np.mean(max_accs_regTopK):.4f}, std = {np.std(max_accs_regTopK):.4f}")
print(f"Min Val Loss:     mean = {np.mean(min_losses_regTopK):.4f}, std = {np.std(min_losses_regTopK):.4f}")
print(f"Last-epoch Val Accuracy: mean = {np.mean(last_accs_regTopK):.4f}, std = {np.std(last_accs_regTopK):.4f}")
print(f"Last-epoch Val Loss:     mean = {np.mean(last_losses_regTopK):.4f}, std = {np.std(last_losses_regTopK):.4f}")
# Out:
# ==== Running with seed 42 ====
# device is mps
# Epoch 1/8 - Loss: 0.4725 - Val Acc: 0.9144
# Epoch 2/8 - Loss: 0.3010 - Val Acc: 0.9279
# Epoch 3/8 - Loss: 0.2114 - Val Acc: 0.9399
# Epoch 4/8 - Loss: 0.1620 - Val Acc: 0.9355
# Epoch 5/8 - Loss: 0.1406 - Val Acc: 0.9414
# Epoch 6/8 - Loss: 0.1473 - Val Acc: 0.9361
# Epoch 7/8 - Loss: 0.1294 - Val Acc: 0.9401
# Epoch 8/8 - Loss: 0.1179 - Val Acc: 0.9411
#
# ==== Running with seed 43 ====
# device is mps
# Epoch 1/8 - Loss: 0.4347 - Val Acc: 0.9343
# Epoch 2/8 - Loss: 0.2792 - Val Acc: 0.9223
# Epoch 3/8 - Loss: 0.2223 - Val Acc: 0.9259
# Epoch 4/8 - Loss: 0.1845 - Val Acc: 0.9343
# Epoch 5/8 - Loss: 0.1443 - Val Acc: 0.9427
# Epoch 6/8 - Loss: 0.1460 - Val Acc: 0.9394
# Epoch 7/8 - Loss: 0.1516 - Val Acc: 0.9386
# Epoch 8/8 - Loss: 0.1187 - Val Acc: 0.9368
#
# ==== Running with seed 44 ====
# device is mps
# Epoch 1/8 - Loss: 0.4890 - Val Acc: 0.9177
# Epoch 2/8 - Loss: 0.3645 - Val Acc: 0.9386
# Epoch 3/8 - Loss: 0.2846 - Val Acc: 0.9220
# Epoch 4/8 - Loss: 0.1934 - Val Acc: 0.9404
# Epoch 5/8 - Loss: 0.1867 - Val Acc: 0.9302
# Epoch 6/8 - Loss: 0.1491 - Val Acc: 0.9236
# Epoch 7/8 - Loss: 0.1737 - Val Acc: 0.9320
# Epoch 8/8 - Loss: 0.1233 - Val Acc: 0.9429
#
# ==== Running with seed 45 ====
# device is mps
# Epoch 1/8 - Loss: 0.5404 - Val Acc: 0.9175
# Epoch 2/8 - Loss: 0.3636 - Val Acc: 0.9205
# Epoch 3/8 - Loss: 0.2386 - Val Acc: 0.9241
# Epoch 4/8 - Loss: 0.1758 - Val Acc: 0.9287
# Epoch 5/8 - Loss: 0.1572 - Val Acc: 0.9470
# Epoch 6/8 - Loss: 0.1526 - Val Acc: 0.9276
# Epoch 7/8 - Loss: 0.1449 - Val Acc: 0.9368
# Epoch 8/8 - Loss: 0.1391 - Val Acc: 0.9325
#
# ==== Running with seed 46 ====
# device is mps
# Epoch 1/8 - Loss: 0.4569 - Val Acc: 0.9381
# Epoch 2/8 - Loss: 0.2485 - Val Acc: 0.9297
# Epoch 3/8 - Loss: 0.2293 - Val Acc: 0.9401
# Epoch 4/8 - Loss: 0.2174 - Val Acc: 0.9366
# Epoch 5/8 - Loss: 0.2457 - Val Acc: 0.9389
# Epoch 6/8 - Loss: 0.1686 - Val Acc: 0.9396
# Epoch 7/8 - Loss: 0.1346 - Val Acc: 0.9315
# Epoch 8/8 - Loss: 0.1404 - Val Acc: 0.9361
#
# ==== Running with seed 51 ====
# device is mps
# Epoch 1/8 - Loss: 0.4078 - Val Acc: 0.8986
# Epoch 2/8 - Loss: 0.4111 - Val Acc: 0.9208
# Epoch 3/8 - Loss: 0.1999 - Val Acc: 0.9422
# Epoch 4/8 - Loss: 0.1759 - Val Acc: 0.9376
# Epoch 5/8 - Loss: 0.1409 - Val Acc: 0.9442
# Epoch 6/8 - Loss: 0.1288 - Val Acc: 0.9442
# Epoch 7/8 - Loss: 0.1417 - Val Acc: 0.9389
# Epoch 8/8 - Loss: 0.1551 - Val Acc: 0.9396
#
# ==== Running with seed 52 ====
# device is mps
# Epoch 1/8 - Loss: 0.4549 - Val Acc: 0.9152
# Epoch 2/8 - Loss: 0.3307 - Val Acc: 0.9312
# Epoch 3/8 - Loss: 0.2376 - Val Acc: 0.9340
# Epoch 4/8 - Loss: 0.2096 - Val Acc: 0.9363
# Epoch 5/8 - Loss: 0.1852 - Val Acc: 0.9419
# Epoch 6/8 - Loss: 0.1829 - Val Acc: 0.9396
# Epoch 7/8 - Loss: 0.1339 - Val Acc: 0.9394
# Epoch 8/8 - Loss: 0.1376 - Val Acc: 0.9406
#
# ==== Running with seed 53 ====
# device is mps
# Epoch 1/8 - Loss: 0.4982 - Val Acc: 0.9159
# Epoch 2/8 - Loss: 0.2889 - Val Acc: 0.9231
# Epoch 3/8 - Loss: 0.2380 - Val Acc: 0.9343
# Epoch 4/8 - Loss: 0.1794 - Val Acc: 0.9411
# Epoch 5/8 - Loss: 0.1702 - Val Acc: 0.9432
# Epoch 6/8 - Loss: 0.1652 - Val Acc: 0.9169
# Epoch 7/8 - Loss: 0.1586 - Val Acc: 0.9389
# Epoch 8/8 - Loss: 0.1637 - Val Acc: 0.9422
#
# ==== Running with seed 54 ====
# device is mps
# Epoch 1/8 - Loss: 0.5175 - Val Acc: 0.8945
# Epoch 2/8 - Loss: 0.4198 - Val Acc: 0.9302
# Epoch 3/8 - Loss: 0.1945 - Val Acc: 0.9445
# Epoch 4/8 - Loss: 0.2008 - Val Acc: 0.9363
# Epoch 5/8 - Loss: 0.2257 - Val Acc: 0.9391
# Epoch 6/8 - Loss: 0.1647 - Val Acc: 0.9399
# Epoch 7/8 - Loss: 0.1547 - Val Acc: 0.9429
# Epoch 8/8 - Loss: 0.1234 - Val Acc: 0.9406
#
# ==== Running with seed 55 ====
# device is mps
# Epoch 1/8 - Loss: 0.4965 - Val Acc: 0.9108
# Epoch 2/8 - Loss: 0.4172 - Val Acc: 0.9141
# Epoch 3/8 - Loss: 0.2346 - Val Acc: 0.9312
# Epoch 4/8 - Loss: 0.1969 - Val Acc: 0.9271
# Epoch 5/8 - Loss: 0.1412 - Val Acc: 0.9432
# Epoch 6/8 - Loss: 0.1501 - Val Acc: 0.9455
# Epoch 7/8 - Loss: 0.1355 - Val Acc: 0.9447
# Epoch 8/8 - Loss: 0.1284 - Val Acc: 0.9450
#
# ===== Summary over seeds for RegTopK =====
# Max Val Accuracy: mean = 0.9433, std = 0.0019
# Min Val Loss:     mean = 0.1307, std = 0.0114
# Last-epoch Val Accuracy: mean = 0.9397, std = 0.0035
# Last-epoch Val Loss:     mean = 0.1348, std = 0.0147

# %%
# Folder and file name
save_dir = "ResNet152"
os.makedirs(save_dir, exist_ok=True)
filename = os.path.join(save_dir, f"RegTopK_{k_frac}.txt")

# Vectors
results = {
    "Max Val Accuracy": max_accs_regTopK,
    "Min Val Loss": min_losses_regTopK,
    "Last-epoch Val Accuracy": last_accs_regTopK,
    "Last-epoch Val Loss": last_losses_regTopK,
}

# Write to file
with open(filename, "w") as f:
    f.write(f"=== RegTopK Results Summary (ResNet152) for k={k_frac} ===\n\n")
    for name, values in results.items():
        mean = np.mean(values)
        std = np.std(values)
        f.write(f"{name}:\n")
        f.write(f"  Values: {np.round(values, 4).tolist()}\n")
        f.write(f"  Mean  : {mean:.4f}\n")
        f.write(f"  Std   : {std:.4f}\n\n")

print(f"Results saved to {filename}")
# Out:
# Results saved to ResNet152/RegTopK_0.01.txt

# %% [markdown]
# #### Checking Statistical Significance

# %%
from scipy.stats import ttest_rel, wilcoxon

# Paired t-test
t_stat, p_val_acc = ttest_rel(max_accs_regTopK, max_accs_topK)
print(f"Paired t-test on Accuracy: p = {p_val_acc:.5f}")

# Paired t-test
t_stat, p_val_loss = ttest_rel(min_losses_regTopK, min_losses_topK)
print(f"Paired t-test on loss: p = {p_val_loss:.5f}")

# Wilcoxon signed-rank test
w_stat, p_val_w_acc = wilcoxon(max_accs_regTopK, max_accs_topK)
print(f"Wilcoxon test on Accuracy: p = {p_val_w_acc:.5f}")

w_stat, p_val_w_loss = wilcoxon(min_losses_regTopK, min_losses_topK)
print(f"Wilcoxon test on loss: p = {p_val_w_loss:.5f}")
# Out:
# Paired t-test on Accuracy: p = 0.71050
# Paired t-test on loss: p = 0.00174
# Wilcoxon test on Accuracy: p = 0.79102
# Wilcoxon test on loss: p = 0.00586

# %%
save_dir = "ResNet152"
os.makedirs(save_dir, exist_ok=True)
filename = os.path.join(save_dir, f"p_values_{k_frac}.txt")

with open(filename, "w") as f:
    f.write(f"=== Statistical Significance (p-values) for k={k_frac} ===\n\n")
    f.write(f"Paired t-test on Accuracy: p = {p_val_acc:.5f}\n")
    f.write(f"Paired t-test on Loss:     p = {p_val_loss:.5f}\n")
    f.write(f"Wilcoxon test on Accuracy: p = {p_val_w_acc:.5f}\n")
    f.write(f"Wilcoxon test on Loss:     p = {p_val_w_loss:.5f}\n")

print(f"\n p-values saved to {filename}")
# Out:
#  p-values saved to ResNet152/p_values_0.001.txt
